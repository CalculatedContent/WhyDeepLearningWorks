# %% [markdown]
# ### All Keras Models
#
# https://keras.io/applications/#available-models

# %%
import numpy as np
import pickle, time
from copy import deepcopy
from shutil import copy
import import_ipynb
from tqdm import tqdm_notebook as tqdm
import RMT_Util

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import keras
from keras.callbacks import TensorBoard, EarlyStopping
from keras.optimizers import SGD
from keras.initializers import Constant
import keras.backend as K

from keras.applications import vgg16, vgg19, inception_resnet_v2, mobilenet, nasnet 

import sklearn
from sklearn.decomposition import TruncatedSVD
from sklearn.random_projection import sparse_random_matrix


print(sys.version)
print("numpy version {}".format(np.__version__))
print("tensforflow version {}".format(tf.__version__))
print("keras version {}".format(keras.__version__))
# Out:
# 3.6.5 |Anaconda custom (64-bit)| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy version 1.14.2
# tensforflow version 1.5.0-dev20171116
# keras version 2.1.5

# %% [markdown]
# ### Fit Marchenko Pastur to ESD

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
alphas = []
#for kmodel in [vgg16.VGG16, vgg19.VGG19, ]:
for kmodel in [inception_resnet_v2]:
    kmodel(weights=None)
    model = kmodel(weights='imagenet')
    for l in model.layers:
        print(l)
        if l.get_weights():
            W = l.get_weights()[0]
            W = RMT_Util.reshape_tensor(W)
            M, N = np.min(W.shape), np.max(W.shape)
            Q=N/M
            
            svd = TruncatedSVD(n_components=M-1, n_iter=7, random_state=10)
            svd.fit(W) 
            sv = svd.singular_values_
            evals_imagenet = sv*sv

            RMT_Util.plot_ESD_and_fit(model=None, eigenvalues=evals_imagenet, layer=None, 
                                        Q=Q, num_spikes=0, sigma=None, color='orange')
            plt.title("Layer ({}x{})".format(M,N))
            plt.show()     

            alpha, D, best = RMT_Util.fit_powerlaw(evals_imagenet)
            print(alpha, D, best)
            alphas.append(alpha)
# Out:
# <keras.engine.topology.InputLayer object at 0x118b43a58>
# <keras.layers.convolutional.Conv2D object at 0x118b2b630>
# (3, 3, 3, 64)
# (27, 64)
# % spikes outside bulk 0.00
# % sigma 3.0599
# RMT_Util.ipynb:7: RuntimeWarning: divide by zero encountered in true_divide
#   "## RMT Util\n",
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in sqrt
#   "## RMT Util\n",
# Calculating best minimal value for power law fit
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Assuming nested distributions
# 1.1856867080642608 0.2360074598332435 TPL
# <keras.layers.convolutional.Conv2D object at 0x118b2be80>
# (3, 3, 64, 64)
# (576, 64)
# % spikes outside bulk 0.00
# % sigma 2.1679
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.2656148344191676 0.2089896971220011 TPL
# <keras.layers.pooling.MaxPooling2D object at 0x104fbb390>
# <keras.layers.convolutional.Conv2D object at 0x11d6f3588>
# (3, 3, 64, 128)
# (576, 128)
# % spikes outside bulk 0.00
# % sigma 1.5636
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.3373022109097885 0.19040517705572585 TPL
# <keras.layers.convolutional.Conv2D object at 0x11d6f3f60>
# (3, 3, 128, 128)
# (1152, 128)
# % spikes outside bulk 0.00
# % sigma 1.3855
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.5383920254229833 0.2179666272881683 TPL
# <keras.layers.pooling.MaxPooling2D object at 0x11d6c97b8>
# <keras.layers.convolutional.Conv2D object at 0x11d698b00>
# (3, 3, 128, 256)
# (1152, 256)
# % spikes outside bulk 0.00
# % sigma 1.3273
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.7439973157628743 0.1603450978700377 PL
# <keras.layers.convolutional.Conv2D object at 0x11d698ef0>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.5651
# Calculating best minimal value for power law fit
# Assuming nested distributions
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:1602: RuntimeWarning: invalid value encountered in true_divide
#   CDF = CDF/norm
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# 5.311602311877624 0.0783515605990312 PL
# <keras.layers.convolutional.Conv2D object at 0x1183de208>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.4138
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.6484994685683056 0.11290631974963927 PL
# <keras.layers.pooling.MaxPooling2D object at 0x11840d320>
# <keras.layers.convolutional.Conv2D object at 0x11d736898>
# (3, 3, 256, 512)
# (2304, 512)
# % spikes outside bulk 0.00
# % sigma 1.1715
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.779130130962064 0.0824680021956456 PL
# <keras.layers.convolutional.Conv2D object at 0x11d733be0>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.5565
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.423251914717167 0.06870826723649284 PL
# <keras.layers.convolutional.Conv2D object at 0x11d701978>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.9612
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.273888511190211 0.07533475594187339 PL
# <keras.layers.pooling.MaxPooling2D object at 0x1043436d8>
# <keras.layers.convolutional.Conv2D object at 0x104374a20>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.4154
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.946452849518284 0.07026601625696022 PL
# <keras.layers.convolutional.Conv2D object at 0x104374e10>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 2.0201
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.79413505941246 0.058753198372498316 PL
# <keras.layers.convolutional.Conv2D object at 0x10439e6d8>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 2.6448
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.9145391874981907 0.0409344301899871 PL
# <keras.layers.pooling.MaxPooling2D object at 0x1073ed278>
# <keras.layers.core.Flatten object at 0x1185227b8>
# <keras.layers.core.Dense object at 0x118522a58>
# (25088, 4096)
# (25088, 4096)
# % spikes outside bulk 0.00
# % sigma 1.7930
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.1128455784572386 0.025649090474994946 TPL
# <keras.layers.core.Dense object at 0x11d593320>
# (4096, 4096)
# (4096, 4096)
# % spikes outside bulk 0.00
# % sigma 1.3976
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in multiply
#   "## RMT Util\n",
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.0334379775819285 0.03389592257667351 TPL
# <keras.layers.core.Dense object at 0x11d61eda0>
# (4096, 1000)
# (4096, 1000)
# % spikes outside bulk 0.00
# % sigma 1.9904
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.0306469484941636 0.03605770403902897 PL
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 215s 0us/step
# <keras.engine.topology.InputLayer object at 0x11854da20>
# <keras.layers.convolutional.Conv2D object at 0x118ef7390>
# (3, 3, 3, 64)
# (27, 64)
# % spikes outside bulk 0.00
# % sigma 2.8087
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.1822756915198116 0.25155631286491 TPL
# <keras.layers.convolutional.Conv2D object at 0x118ef7a90>
# (3, 3, 64, 64)
# (576, 64)
# % spikes outside bulk 0.00
# % sigma 1.9824
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.2526587886664615 0.20062778322750785 TPL
# <keras.layers.pooling.MaxPooling2D object at 0x11be1a5c0>
# <keras.layers.convolutional.Conv2D object at 0x13910df98>
# (3, 3, 64, 128)
# (576, 128)
# % spikes outside bulk 0.00
# % sigma 1.4007
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.3735413295735959 0.18976959327208104 TPL
# <keras.layers.convolutional.Conv2D object at 0x139043b38>
# (3, 3, 128, 128)
# (1152, 128)
# % spikes outside bulk 0.00
# % sigma 1.2933
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.478246937325355 0.20482019523757822 PL
# <keras.layers.pooling.MaxPooling2D object at 0x139076e80>
# <keras.layers.convolutional.Conv2D object at 0x11bd5e668>
# (3, 3, 128, 256)
# (1152, 256)
# % spikes outside bulk 0.00
# % sigma 1.1839
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.1736663985120677 0.17033137576534507 TPL
# <keras.layers.convolutional.Conv2D object at 0x11bd5e940>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.3892
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.992737554704982 0.1073295889214976 PL
# <keras.layers.convolutional.Conv2D object at 0x139103550>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.4968
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.4110320712535227 0.12021940319155078 TPL
# <keras.layers.convolutional.Conv2D object at 0x11839dbe0>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.2907
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.789257129194646 0.1415422600567181 PL
# <keras.layers.pooling.MaxPooling2D object at 0x1390e7a58>
# <keras.layers.convolutional.Conv2D object at 0x138f9f550>
# (3, 3, 256, 512)
# (2304, 512)
# % spikes outside bulk 0.00
# % sigma 1.0664
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.8522080586294547 0.13127169559015395 PL
# <keras.layers.convolutional.Conv2D object at 0x138f9fcc0>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.1278
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.5845097030612902 0.12036571396697121 TPL
# <keras.layers.convolutional.Conv2D object at 0x138f89cc0>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.5239
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.243003634589242 0.0714285714285735 PL
# <keras.layers.convolutional.Conv2D object at 0x138ffc9b0>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.8112
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.488925842700516 0.06613548155700832 PL
# <keras.layers.pooling.MaxPooling2D object at 0x138fda0f0>
# <keras.layers.convolutional.Conv2D object at 0x138f76668>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.1661
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.7044510146125664 0.10856315837271707 TPL
# <keras.layers.convolutional.Conv2D object at 0x138f760f0>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.5265
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.404243337576017 0.07310181142548744 PL
# <keras.layers.convolutional.Conv2D object at 0x138f6b940>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 1.9904
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.761462733036178 0.042036480342301896 PL
# <keras.layers.convolutional.Conv2D object at 0x11bdf0ac8>
# (3, 3, 512, 512)
# (4608, 512)
# % spikes outside bulk 0.00
# % sigma 2.4856
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.020071797718712 0.040993540457002764 PL
# <keras.layers.pooling.MaxPooling2D object at 0x118874b70>
# <keras.layers.core.Flatten object at 0x118a6a978>
# <keras.layers.core.Dense object at 0x118a6af60>
# (25088, 4096)
# (25088, 4096)
# % spikes outside bulk 0.00
# % sigma 1.8244
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.1375509317441246 0.02586956513725075 TPL
# <keras.layers.core.Dense object at 0x11a786eb8>
# (4096, 4096)
# (4096, 4096)
# % spikes outside bulk 0.00
# % sigma 1.4116
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.0549795096258405 0.033641967259435246 TPL
# <keras.layers.core.Dense object at 0x11a788b38>
# (4096, 1000)
# (4096, 1000)
# % spikes outside bulk 0.00
# % sigma 2.0290
# Calculating best minimal value for power law fit
# 2.9806384939829855 0.031132842843849096 PL
# Assuming nested distributions

# %%
print(len(alphas))
plt.hist(alphas,bins=50);
# Out:
# 35

# %%
def analyze_model(model):
    alphas = []
    for l in model.layers:
        print(l)
        if l.get_weights():
            W = l.get_weights()[0]
            W = RMT_Util.reshape_tensor(W)
            M, N = np.min(W.shape), np.max(W.shape)
            if ((N>43) and (M>43)):
                Q=N/M

                svd = TruncatedSVD(n_components=M-1, n_iter=7, random_state=10)
                svd.fit(W) 
                sv = svd.singular_values_
                evals_imagenet = sv*sv

                RMT_Util.plot_ESD_and_fit(model=None, eigenvalues=evals_imagenet, layer=None, 
                                            Q=Q, num_spikes=0, sigma=None, color='orange')
                plt.title("Layer ({}x{})".format(M,N))
                plt.show()     

                alpha, D, best = RMT_Util.fit_powerlaw(evals_imagenet)
                print(alpha, D, best)
                alphas.append(alpha)
    return alphas

# %%
for kmodel in [inception_resnet_v2.InceptionResNetV2]:
    kmodel(weights=None)
    model = kmodel(weights='imagenet')
    alphas = analyze_model(model)
# Out:
# <keras.engine.topology.InputLayer object at 0x243b517b8>
# <keras.layers.convolutional.Conv2D object at 0x243b3da58>
# (3, 3, 3, 32)
# (27, 32)
# <keras.layers.normalization.BatchNormalization object at 0x243b3d908>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x243b326a0>
# <keras.layers.convolutional.Conv2D object at 0x243b324e0>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.normalization.BatchNormalization object at 0x243b15e10>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x243ad64a8>
# <keras.layers.convolutional.Conv2D object at 0x243aa3048>
# (3, 3, 32, 64)
# (288, 64)
# % spikes outside bulk 0.00
# % sigma 3.1251
# RMT_Util.ipynb:7: RuntimeWarning: divide by zero encountered in true_divide
#   "## RMT Util\n",
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in sqrt
#   "## RMT Util\n",
# Calculating best minimal value for power law fit
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Assuming nested distributions
# 2.006665373213071 0.16606780175398816 TPL
# <keras.layers.normalization.BatchNormalization object at 0x243abf2e8>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x243a707f0>
# <keras.layers.pooling.MaxPooling2D object at 0x243a5a978>
# <keras.layers.convolutional.Conv2D object at 0x243a45128>
# (1, 1, 64, 80)
# (64, 80)
# % spikes outside bulk 0.00
# % sigma 1.7729
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.728863978509836 0.18661008075425234 PL
# <keras.layers.normalization.BatchNormalization object at 0x2439fe860>
# (80,)
# (1, 80)
# <keras.layers.core.Activation object at 0x2439f23c8>
# <keras.layers.convolutional.Conv2D object at 0x2439ebe10>
# (3, 3, 80, 192)
# (720, 192)
# % spikes outside bulk 0.00
# % sigma 3.0537
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.326618143613722 0.09971513167576568 PL
# <keras.layers.normalization.BatchNormalization object at 0x2439d5710>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x2439971d0>
# <keras.layers.pooling.MaxPooling2D object at 0x243980710>
# <keras.layers.convolutional.Conv2D object at 0x243835358>
# (1, 1, 192, 64)
# (192, 64)
# % spikes outside bulk 0.00
# % sigma 1.5182
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.046789743381798 0.19442742874869434 PL
# <keras.layers.normalization.BatchNormalization object at 0x243823b00>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2437e6908>
# <keras.layers.convolutional.Conv2D object at 0x2439104e0>
# (1, 1, 192, 48)
# (192, 48)
# <keras.layers.convolutional.Conv2D object at 0x2437cfcf8>
# (3, 3, 64, 96)
# (576, 96)
# % spikes outside bulk 0.00
# % sigma 1.6831
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.6661202173429663 0.15970508409923478 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2438fb630>
# (48,)
# (1, 48)
# <keras.layers.normalization.BatchNormalization object at 0x2437bc550>
# (96,)
# (1, 96)
# <keras.layers.core.Activation object at 0x2438be278>
# <keras.layers.core.Activation object at 0x24377f2b0>
# <keras.layers.pooling.AveragePooling2D object at 0x2436f9320>
# <keras.layers.convolutional.Conv2D object at 0x243964400>
# (1, 1, 192, 96)
# (192, 96)
# % spikes outside bulk 0.00
# % sigma 4.2557
# Calculating best minimal value for power law fit
# Assuming nested distributions
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:1602: RuntimeWarning: invalid value encountered in true_divide
#   CDF = CDF/norm
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# 3.094969456509069 0.07698611010474299 PL
# <keras.layers.convolutional.Conv2D object at 0x24386b278>
# (5, 5, 48, 64)
# (1200, 64)
# % spikes outside bulk 0.00
# % sigma 2.7747
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.266178715014387 0.20899750780574577 PL
# <keras.layers.convolutional.Conv2D object at 0x243768908>
# (3, 3, 96, 96)
# (864, 96)
# % spikes outside bulk 0.00
# % sigma 4.1225
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.284557747911143 0.10836968944277178 PL
# <keras.layers.convolutional.Conv2D object at 0x2436e4a20>
# (1, 1, 192, 64)
# (192, 64)
# % spikes outside bulk 0.00
# % sigma 2.2698
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.031406532181419 0.10169185169655648 PL
# <keras.layers.normalization.BatchNormalization object at 0x243926cc0>
# (96,)
# (1, 96)
# <keras.layers.normalization.BatchNormalization object at 0x243894160>
# (64,)
# (1, 64)
# <keras.layers.normalization.BatchNormalization object at 0x2437544a8>
# (96,)
# (1, 96)
# <keras.layers.normalization.BatchNormalization object at 0x2436a5c50>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2439105c0>
# <keras.layers.core.Activation object at 0x2438422b0>
# <keras.layers.core.Activation object at 0x243705cf8>
# <keras.layers.core.Activation object at 0x243693be0>
# <keras.layers.merge.Concatenate object at 0x243693c50>
# <keras.layers.convolutional.Conv2D object at 0x243546240>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x243533da0>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x2434f56d8>
# <keras.layers.convolutional.Conv2D object at 0x243620400>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2434e1550>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x24360b780>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2434cc7b8>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x2435cd198>
# <keras.layers.core.Activation object at 0x24348e390>
# <keras.layers.convolutional.Conv2D object at 0x243693320>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2435b9b00>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x243479908>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.0663
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.270961237550468 0.1410947996749808 PL
# <keras.layers.normalization.BatchNormalization object at 0x24367b208>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2435670b8>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x243471400>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2436292e8>
# <keras.layers.core.Activation object at 0x2435514a8>
# <keras.layers.core.Activation object at 0x243412358>
# <keras.layers.merge.Concatenate object at 0x243407c88>
# <keras.layers.convolutional.Conv2D object at 0x243407630>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 5.7572
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 1.9171046475282059 0.040604930612614165 PL
# <keras.layers.core.Lambda object at 0x2433f3cc0>
# <keras.layers.core.Activation object at 0x2433b6ac8>
# <keras.layers.convolutional.Conv2D object at 0x2432b4c18>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24329f4a8>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x243262128>
# <keras.layers.convolutional.Conv2D object at 0x24338c668>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x24324c5c0>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x24336e278>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24322eeb8>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x243323128>
# <keras.layers.core.Activation object at 0x2431eeb00>
# <keras.layers.convolutional.Conv2D object at 0x2433a0550>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x24331ccc0>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x2431bc4a8>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.0624
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7286036228542172 0.1635400613666883 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2433a04e0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2433078d0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2431db7b8>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x24338c748>
# <keras.layers.core.Activation object at 0x2432c7668>
# <keras.layers.core.Activation object at 0x24318c470>
# <keras.layers.merge.Concatenate object at 0x2431737f0>
# <keras.layers.convolutional.Conv2D object at 0x243173240>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.7920
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.981239348035076 0.1074880939894658 PL
# <keras.layers.core.Lambda object at 0x24315f2b0>
# <keras.layers.core.Activation object at 0x24310d908>
# <keras.layers.convolutional.Conv2D object at 0x2430161d0>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2430019b0>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x242fc4780>
# <keras.layers.convolutional.Conv2D object at 0x2430eeda0>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242faf4e0>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x2430da588>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242f9c518>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x24309ae80>
# <keras.layers.core.Activation object at 0x242f5c0f0>
# <keras.layers.convolutional.Conv2D object at 0x243118f28>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x243072080>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x242f47748>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.1955
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.787896125407128 0.1608414406871117 PL
# <keras.layers.normalization.BatchNormalization object at 0x243103b00>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x243089fd0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242f27908>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2430ee080>
# <keras.layers.core.Activation object at 0x24301f198>
# <keras.layers.core.Activation object at 0x242ee0128>
# <keras.layers.merge.Concatenate object at 0x242ed59b0>
# <keras.layers.convolutional.Conv2D object at 0x242ed55c0>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.6714
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.4954611448576274 0.13670943793627433 PL
# <keras.layers.core.Lambda object at 0x242ec2c50>
# <keras.layers.core.Activation object at 0x242e70a58>
# <keras.layers.convolutional.Conv2D object at 0x242d848d0>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242d30048>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x242d1cfd0>
# <keras.layers.convolutional.Conv2D object at 0x242e5b048>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242d113c8>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x242e3ccf8>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242cfbb70>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x242dfd860>
# <keras.layers.core.Activation object at 0x242cbe940>
# <keras.layers.convolutional.Conv2D object at 0x242e83710>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242deb198>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x242caaeb8>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.1050
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8736950139331503 0.14953671115636213 TPL
# <keras.layers.normalization.BatchNormalization object at 0x242e660f0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242dd36a0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242c96780>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x242e4e4a8>
# <keras.layers.core.Activation object at 0x242d96518>
# <keras.layers.core.Activation object at 0x242c58320>
# <keras.layers.merge.Concatenate object at 0x242c39898>
# <keras.layers.convolutional.Conv2D object at 0x242c39240>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.2154
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.1789826643135495 0.1423152276042789 PL
# <keras.layers.core.Lambda object at 0x242c2f0f0>
# <keras.layers.core.Activation object at 0x242bdd828>
# <keras.layers.convolutional.Conv2D object at 0x242ae4f98>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242ace7b8>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x242a91438>
# <keras.layers.convolutional.Conv2D object at 0x242bbcc18>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242a7d4a8>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x242ba7400>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242a357f0>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x242b5fb38>
# <keras.layers.core.Activation object at 0x242a1ffd0>
# <keras.layers.convolutional.Conv2D object at 0x242be6f60>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242b54f28>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x242a167f0>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.5266
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.9087552471247784 0.12302842271761077 TPL
# <keras.layers.normalization.BatchNormalization object at 0x242bc56a0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242b36dd8>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2429f8940>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x242bbcda0>
# <keras.layers.core.Activation object at 0x242af7978>
# <keras.layers.core.Activation object at 0x2429b9eb8>
# <keras.layers.merge.Concatenate object at 0x242987048>
# <keras.layers.convolutional.Conv2D object at 0x242993b38>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.2388
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.0198199775046097 0.1660320624919821 TPL
# <keras.layers.core.Lambda object at 0x24294f2b0>
# <keras.layers.core.Activation object at 0x24293e8d0>
# <keras.layers.convolutional.Conv2D object at 0x24283b048>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24284f710>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x2427ea198>
# <keras.layers.convolutional.Conv2D object at 0x24291f128>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2427de1d0>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x24290b0f0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2427c89e8>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x2428cc6d8>
# <keras.layers.core.Activation object at 0x24278c7b8>
# <keras.layers.convolutional.Conv2D object at 0x242948ba8>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2428b91d0>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x242778ac8>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 0.9993
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.326106128047641 0.12559123975398057 PL
# <keras.layers.normalization.BatchNormalization object at 0x242933240>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2428a2518>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242725198>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x242929278>
# <keras.layers.core.Activation object at 0x242864160>
# <keras.layers.core.Activation object at 0x24271beb8>
# <keras.layers.merge.Concatenate object at 0x2427105c0>
# <keras.layers.convolutional.Conv2D object at 0x2427100b8>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.0578
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.48989867758764 0.18411157886095875 PL
# <keras.layers.core.Lambda object at 0x2426f1d30>
# <keras.layers.core.Activation object at 0x2426b5be0>
# <keras.layers.convolutional.Conv2D object at 0x2425b0cf8>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24259e0b8>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x242561160>
# <keras.layers.convolutional.Conv2D object at 0x242676198>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242534550>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x24268b748>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24254b3c8>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x242621278>
# <keras.layers.core.Activation object at 0x2424e5160>
# <keras.layers.convolutional.Conv2D object at 0x24269f5f8>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242618f28>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x2424da198>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.1480
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.824018490519867 0.12995932760141893 TPL
# <keras.layers.normalization.BatchNormalization object at 0x242695320>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242605b00>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2424bab38>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x24268ba20>
# <keras.layers.core.Activation object at 0x2425c7780>
# <keras.layers.core.Activation object at 0x24247b630>
# <keras.layers.merge.Concatenate object at 0x242468c50>
# <keras.layers.convolutional.Conv2D object at 0x2424686a0>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.1390
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.632133465706507 0.15563539205313892 TPL
# <keras.layers.core.Lambda object at 0x242452438>
# <keras.layers.core.Activation object at 0x242402320>
# <keras.layers.convolutional.Conv2D object at 0x242301320>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2422ebcc0>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x2422af5f8>
# <keras.layers.convolutional.Conv2D object at 0x2423e1dd8>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242299d30>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x2423cd5c0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x242285438>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x2423901d0>
# <keras.layers.core.Activation object at 0x2422460b8>
# <keras.layers.convolutional.Conv2D object at 0x242418c50>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2423650b8>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x2422315f8>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.3885
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7310032850752843 0.11706903694739779 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2423f6b00>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x24237c780>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2421fde80>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2423e10b8>
# <keras.layers.core.Activation object at 0x24230b278>
# <keras.layers.core.Activation object at 0x2421d49e8>
# <keras.layers.merge.Concatenate object at 0x2421c0390>
# <keras.layers.convolutional.Conv2D object at 0x2421c0b38>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.4197
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6330488921318436 0.11804391917131618 PL
# <keras.layers.core.Lambda object at 0x24216c518>
# <keras.layers.core.Activation object at 0x242158828>
# <keras.layers.convolutional.Conv2D object at 0x24206b780>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2420580b8>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x241ff1400>
# <keras.layers.convolutional.Conv2D object at 0x24213b8d0>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x242004390>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x242124ba8>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241fe6c18>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x2420e6908>
# <keras.layers.core.Activation object at 0x241fa87b8>
# <keras.layers.convolutional.Conv2D object at 0x2421643c8>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x2420d2e80>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x241f94d30>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.1146
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.6730483467709392 0.21466418254526898 TPL
# <keras.layers.normalization.BatchNormalization object at 0x24214c128>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2420c0748>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241f80fd0>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x242144470>
# <keras.layers.core.Activation object at 0x2420822e8>
# <keras.layers.core.Activation object at 0x241f41390>
# <keras.layers.merge.Concatenate object at 0x241f2e0b8>
# <keras.layers.convolutional.Conv2D object at 0x241f2eba8>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 1.1705
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.9525524174782576 0.15081470565549948 TPL
# <keras.layers.core.Lambda object at 0x241f18ba8>
# <keras.layers.core.Activation object at 0x241ece780>
# <keras.layers.convolutional.Conv2D object at 0x241dcd550>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241db9cf8>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x241d7a518>
# <keras.layers.convolutional.Conv2D object at 0x241ea6550>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x241d66b70>
# (3, 3, 32, 48)
# (288, 48)
# <keras.layers.normalization.BatchNormalization object at 0x241e93588>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241d53358>
# (48,)
# (1, 48)
# <keras.layers.core.Activation object at 0x241e52048>
# <keras.layers.core.Activation object at 0x241d0a518>
# <keras.layers.convolutional.Conv2D object at 0x241ece940>
# (1, 1, 320, 32)
# (320, 32)
# <keras.layers.convolutional.Conv2D object at 0x241e3f860>
# (3, 3, 32, 32)
# (288, 32)
# <keras.layers.convolutional.Conv2D object at 0x241d00550>
# (3, 3, 48, 64)
# (432, 64)
# % spikes outside bulk 0.00
# % sigma 1.6049
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.6977038959858737 0.11930073386280737 PL
# <keras.layers.normalization.BatchNormalization object at 0x241eb04a8>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241e1f9b0>
# (32,)
# (1, 32)
# <keras.layers.normalization.BatchNormalization object at 0x241ce2e48>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x241ea66d8>
# <keras.layers.core.Activation object at 0x241dd8080>
# <keras.layers.core.Activation object at 0x241ca19e8>
# <keras.layers.merge.Concatenate object at 0x241c6fd68>
# <keras.layers.convolutional.Conv2D object at 0x241c796d8>
# (1, 1, 128, 320)
# (128, 320)
# % spikes outside bulk 0.00
# % sigma 2.3566
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 2.5193032205890264 0.05821141488535664 PL
# <keras.layers.core.Lambda object at 0x241c3d320>
# <keras.layers.core.Activation object at 0x241c27860>
# <keras.layers.convolutional.Conv2D object at 0x241c09358>
# (1, 1, 320, 256)
# (320, 256)
# % spikes outside bulk 0.00
# % sigma 1.2082
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7562180201675055 0.13854646596459147 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241bf3b00>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x241bb6860>
# <keras.layers.convolutional.Conv2D object at 0x241b9fc18>
# (3, 3, 256, 256)
# (2304, 256)
# % spikes outside bulk 0.00
# % sigma 1.7626
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.682032945927453 0.061345917220833934 PL
# <keras.layers.normalization.BatchNormalization object at 0x241b8d550>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x241b4d278>
# <keras.layers.convolutional.Conv2D object at 0x241c33518>
# (3, 3, 320, 384)
# (2880, 384)
# % spikes outside bulk 0.00
# % sigma 3.8631
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.3392206017607453 0.06733873765027243 PL
# <keras.layers.convolutional.Conv2D object at 0x241b39898>
# (3, 3, 256, 384)
# (2304, 384)
# % spikes outside bulk 0.00
# % sigma 2.5938
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.41920308417907 0.10207231909840664 PL
# <keras.layers.normalization.BatchNormalization object at 0x241c1d208>
# (384,)
# (1, 384)
# <keras.layers.normalization.BatchNormalization object at 0x241b249b0>
# (384,)
# (1, 384)
# <keras.layers.core.Activation object at 0x241c15f28>
# <keras.layers.core.Activation object at 0x241ad32b0>
# <keras.layers.pooling.MaxPooling2D object at 0x241ac9358>
# <keras.layers.merge.Concatenate object at 0x241ab3a20>
# <keras.layers.convolutional.Conv2D object at 0x241a62a58>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.7895
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.4675852158843485 0.12329428449400492 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241a42dd8>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x241a06b00>
# <keras.layers.convolutional.Conv2D object at 0x2419f0e80>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.3150
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.518636154994434 0.15528864980730622 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2419e4940>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x24199e080>
# <keras.layers.convolutional.Conv2D object at 0x241a96320>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8690
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.3386938004106406 0.09494552858606076 TPL
# <keras.layers.convolutional.Conv2D object at 0x24198ab70>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.7132
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7144541939706077 0.11599021832257067 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241a75748>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x241972f28>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x241a62a90>
# <keras.layers.core.Activation object at 0x24192db38>
# <keras.layers.merge.Concatenate object at 0x241921550>
# <keras.layers.convolutional.Conv2D object at 0x241921160>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 3.5054
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8638612625244126 0.056572383500115064 PL
# <keras.layers.core.Lambda object at 0x241904e10>
# <keras.layers.core.Activation object at 0x2418c5ba8>
# <keras.layers.convolutional.Conv2D object at 0x24189d860>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.2749
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.625243982567396 0.14633852976064526 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2418885f8>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2418342b0>
# <keras.layers.convolutional.Conv2D object at 0x24182b358>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.1599
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7411025284393786 0.13792084297060514 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241814978>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x2417c2860>
# <keras.layers.convolutional.Conv2D object at 0x2418b2d68>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8391
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.8250901659884065 0.17231441998517938 PL
# <keras.layers.convolutional.Conv2D object at 0x2417cc7f0>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.2810
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8880863207773337 0.12853103895476814 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2418a8240>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x2417afd30>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x24189d9e8>
# <keras.layers.core.Activation object at 0x241770128>
# <keras.layers.merge.Concatenate object at 0x241748128>
# <keras.layers.convolutional.Conv2D object at 0x24173ff98>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.8643
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.5767965021345036 0.07281239954710361 PL
# <keras.layers.core.Lambda object at 0x24175b208>
# <keras.layers.core.Activation object at 0x2417004e0>
# <keras.layers.convolutional.Conv2D object at 0x2416d8c18>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.3850
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.6827229764250695 0.14369445575701334 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2416c0470>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2416794a8>
# <keras.layers.convolutional.Conv2D object at 0x24166e630>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.2831
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.689830798891062 0.1566977822753719 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241651748>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x241613cc0>
# <keras.layers.convolutional.Conv2D object at 0x2417006a0>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8322
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.0032286549524922 0.18793335531598465 TPL
# <keras.layers.convolutional.Conv2D object at 0x2416009b0>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.4166
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7730270789961033 0.12782814900293094 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2416e2470>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x2415e9940>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x2416d8da0>
# <keras.layers.core.Activation object at 0x2415ab4e0>
# <keras.layers.merge.Concatenate object at 0x241599b38>
# <keras.layers.convolutional.Conv2D object at 0x2415995c0>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.7072
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6563954025130694 0.0671813553410805 PL
# <keras.layers.core.Lambda object at 0x241584320>
# <keras.layers.core.Activation object at 0x241530358>
# <keras.layers.convolutional.Conv2D object at 0x241510e48>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.3467
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7543607305170885 0.14527137898356757 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2414fd630>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x23e05cd68>
# <keras.layers.convolutional.Conv2D object at 0x2414ae400>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.1723
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.2768571013202363 0.16241349102542402 TPL
# <keras.layers.normalization.BatchNormalization object at 0x241499c50>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x24145c7f0>
# <keras.layers.convolutional.Conv2D object at 0x24153aa90>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.9438
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.779873050546145 0.14352823652592428 PL
# <keras.layers.convolutional.Conv2D object at 0x241447b70>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.2617
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.738083131114193 0.13924432405886578 PL
# <keras.layers.normalization.BatchNormalization object at 0x241524cc0>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x241433dd8>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x24151be80>
# <keras.layers.core.Activation object at 0x2413f3320>
# <keras.layers.merge.Concatenate object at 0x2413e0908>
# <keras.layers.convolutional.Conv2D object at 0x2413e02b0>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.3820
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6717414448931898 0.1127693842023949 TPL
# <keras.layers.core.Lambda object at 0x2413cb048>
# <keras.layers.core.Activation object at 0x241378208>
# <keras.layers.convolutional.Conv2D object at 0x24135c390>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.5413
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.0899138374970985 0.13933952957962037 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2413465c0>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2413060b8>
# <keras.layers.convolutional.Conv2D object at 0x2412f46d8>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.2779
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8607338030052711 0.1719029808121404 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2412d57f0>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x24128c0f0>
# <keras.layers.convolutional.Conv2D object at 0x2413846d8>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8853
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.473364082943336 0.1668787195176351 TPL
# <keras.layers.convolutional.Conv2D object at 0x241283128>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.4084
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.918481610627557 0.1342817322728781 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2413654e0>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x24126fb38>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x24135c518>
# <keras.layers.core.Activation object at 0x241230588>
# <keras.layers.merge.Concatenate object at 0x24121bbe0>
# <keras.layers.convolutional.Conv2D object at 0x24121b668>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.5842
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.081245287958391 0.09445460454222554 PL
# <keras.layers.core.Lambda object at 0x2412083c8>
# <keras.layers.core.Activation object at 0x2411b4400>
# <keras.layers.convolutional.Conv2D object at 0x241194ef0>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.4857
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.4708930361560952 0.1512519628250133 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2411806d8>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x241142278>
# <keras.layers.convolutional.Conv2D object at 0x24112e9b0>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.1152
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7083698816390833 0.1802487705369139 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2410dd048>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x2410c7080>
# <keras.layers.convolutional.Conv2D object at 0x2411bcdd8>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.9411
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 7.008451138898981 0.11576461514667291 PL
# <keras.layers.convolutional.Conv2D object at 0x2410bb5f8>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.3045
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.4971020466894776 0.1217881017264123 PL
# <keras.layers.normalization.BatchNormalization object at 0x2411aa0f0>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x2410a6be0>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x24119f3c8>
# <keras.layers.core.Activation object at 0x24106b940>
# <keras.layers.merge.Concatenate object at 0x241058eb8>
# <keras.layers.convolutional.Conv2D object at 0x2410587f0>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.4593
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.845049160789854 0.08707419222701429 TPL
# <keras.layers.core.Lambda object at 0x241004198>
# <keras.layers.core.Activation object at 0x240fee588>
# <keras.layers.convolutional.Conv2D object at 0x240fcd128>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.3857
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.79118774199177 0.14174475442337753 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240fbaa58>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x240f7c5c0>
# <keras.layers.convolutional.Conv2D object at 0x240f69b70>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.2409
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7035449808269127 0.1554205845408348 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240f53400>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x240f18048>
# <keras.layers.convolutional.Conv2D object at 0x240ff9d30>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.9201
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.1612641215193107 0.13591951979214234 TPL
# <keras.layers.convolutional.Conv2D object at 0x240f01f60>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.3423
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7873587683061896 0.14844555452487357 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240fe4160>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x240ee3ef0>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x240fdb828>
# <keras.layers.core.Activation object at 0x240ea3a90>
# <keras.layers.merge.Concatenate object at 0x240e8e550>
# <keras.layers.convolutional.Conv2D object at 0x240e8eb00>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.3944
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.438479716910448 0.11087071254061331 TPL
# <keras.layers.core.Lambda object at 0x240e3d588>
# <keras.layers.core.Activation object at 0x240e282e8>
# <keras.layers.convolutional.Conv2D object at 0x240e09400>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.2644
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.1496192617466368 0.16275702323771174 PL
# <keras.layers.normalization.BatchNormalization object at 0x240df4be0>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x240db8940>
# <keras.layers.convolutional.Conv2D object at 0x240da0940>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.1175
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.9724402560409249 0.1750343603188399 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240d8f588>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x240d4e320>
# <keras.layers.convolutional.Conv2D object at 0x240e335f8>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8294
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.525338027435751 0.1468837711799562 PL
# <keras.layers.convolutional.Conv2D object at 0x240d3bc88>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.1720
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.4985641102747995 0.13941803562873517 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240e1c0b8>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x240d26048>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x240e13710>
# <keras.layers.core.Activation object at 0x240cd5358>
# <keras.layers.merge.Concatenate object at 0x240ccbba8>
# <keras.layers.convolutional.Conv2D object at 0x240ccba90>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.3647
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.5156932990793877 0.10242516356839987 PL
# <keras.layers.core.Lambda object at 0x240cb60f0>
# <keras.layers.core.Activation object at 0x240c78940>
# <keras.layers.convolutional.Conv2D object at 0x240c4c668>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.5884
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.052946905237898 0.10724097627771112 PL
# <keras.layers.normalization.BatchNormalization object at 0x240c30f60>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x240be90b8>
# <keras.layers.convolutional.Conv2D object at 0x240bde7f0>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.1411
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.8124600088059997 0.14945932539081963 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240bc7908>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x240b8b588>
# <keras.layers.convolutional.Conv2D object at 0x240c64470>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.8944
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.267903944750466 0.11869588108952822 PL
# <keras.layers.convolutional.Conv2D object at 0x240b77b00>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.2783
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.142866405420387 0.14579284220385147 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240c643c8>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x240b62390>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x240c4c7f0>
# <keras.layers.core.Activation object at 0x240b17be0>
# <keras.layers.merge.Concatenate object at 0x240b0e588>
# <keras.layers.convolutional.Conv2D object at 0x240b0e128>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.5139
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6765508192841656 0.09436581771397307 TPL
# <keras.layers.core.Lambda object at 0x240aeedd8>
# <keras.layers.core.Activation object at 0x240aa7940>
# <keras.layers.convolutional.Conv2D object at 0x240a89a20>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.3881
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.351539826185448 0.13150326196225215 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240a74be0>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x240a21390>
# <keras.layers.convolutional.Conv2D object at 0x240a195c0>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.3798
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.883671077033863 0.11483210637974883 PL
# <keras.layers.normalization.BatchNormalization object at 0x240a03c88>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x2409c48d0>
# <keras.layers.convolutional.Conv2D object at 0x240aa7ba8>
# (1, 1, 1088, 192)
# (1088, 192)
# % spikes outside bulk 0.00
# % sigma 0.9995
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.956119936280057 0.08337680849880469 PL
# <keras.layers.convolutional.Conv2D object at 0x2409b0e48>
# (7, 1, 160, 192)
# (1120, 192)
# % spikes outside bulk 0.00
# % sigma 1.3774
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.1192473992604794 0.12929424289608366 TPL
# <keras.layers.normalization.BatchNormalization object at 0x240a932b0>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x24099c6d8>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x240a89ba8>
# <keras.layers.core.Activation object at 0x24095e2b0>
# <keras.layers.merge.Concatenate object at 0x240949518>
# <keras.layers.convolutional.Conv2D object at 0x240949cf8>
# (1, 1, 384, 1088)
# (384, 1088)
# % spikes outside bulk 0.00
# % sigma 1.6173
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.707898993855717 0.07754353344992015 TPL
# <keras.layers.core.Lambda object at 0x240936080>
# <keras.layers.core.Activation object at 0x2408e34e0>
# <keras.layers.convolutional.Conv2D object at 0x2408c3c18>
# (1, 1, 1088, 128)
# (1088, 128)
# % spikes outside bulk 0.00
# % sigma 1.4011
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8106978713354487 0.15635924820766833 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2408b1400>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x240867ba8>
# <keras.layers.convolutional.Conv2D object at 0x24085f5c0>
# (1, 7, 128, 160)
# (896, 160)
# % spikes outside bulk 0.00
# % sigma 1.2650
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.151428190363883 0.15790174297082116 TPL
# <keras.layers.normalization.BatchNormalization object at 0x24083feb8>
# (160,)
# (1, 160)
# <keras.layers.core.Activation object at 0x2407ffa90>
# ...
# <keras.layers.convolutional.Conv2D object at 0x23ec35a20>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 0.7795
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 7.118082430164616 0.0845019417759737 PL
# <keras.layers.normalization.BatchNormalization object at 0x23ed19d30>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23ebe4048>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23ed064e0>
# <keras.layers.core.Activation object at 0x23ebd92e8>
# <keras.layers.merge.Concatenate object at 0x23ebd1400>
# <keras.layers.convolutional.Conv2D object at 0x23ebc44a8>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 1.2399
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 7.683495852371245 0.06732399273845435 PL
# <keras.layers.core.Lambda object at 0x23ebb1cf8>
# <keras.layers.core.Activation object at 0x23eb70a20>
# <keras.layers.convolutional.Conv2D object at 0x23eb36048>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 1.6519
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 6.0140336931662075 0.09527976274394967 PL
# <keras.layers.normalization.BatchNormalization object at 0x23eb49710>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x23eae3160>
# <keras.layers.convolutional.Conv2D object at 0x23ead9198>
# (1, 3, 192, 224)
# (576, 224)
# % spikes outside bulk 0.00
# % sigma 0.6393
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 15.311148764876192 0.14285714285714335 LOG_N
# <keras.layers.normalization.BatchNormalization object at 0x23eac49b0>
# (224,)
# (1, 224)
# <keras.layers.core.Activation object at 0x23ea85588>
# <keras.layers.convolutional.Conv2D object at 0x23eb5d518>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 0.8912
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 11.377127372946761 0.10776106760077991 LOG_N
# <keras.layers.convolutional.Conv2D object at 0x23ea70b70>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 0.7606
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.587935348290103 0.09959398514069684 PL
# <keras.layers.normalization.BatchNormalization object at 0x23eb53860>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23ea5b438>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23eb49898>
# <keras.layers.core.Activation object at 0x23ea1d160>
# <keras.layers.merge.Concatenate object at 0x23ea0a0b8>
# <keras.layers.convolutional.Conv2D object at 0x23ea0a668>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 1.4673
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 6.067355068216205 0.07874157346117805 PL
# <keras.layers.core.Lambda object at 0x23e9ebfd0>
# <keras.layers.core.Activation object at 0x23e9a3198>
# <keras.layers.convolutional.Conv2D object at 0x23e985a90>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 2.4500
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.757163986401908 0.09737087711129544 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e9320f0>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x23e91def0>
# <keras.layers.convolutional.Conv2D object at 0x23e9125c0>
# (1, 3, 192, 224)
# (576, 224)
# % spikes outside bulk 0.00
# % sigma 0.7171
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 8.986833069250725 0.07142857142857173 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e8fcd30>
# (224,)
# (1, 224)
# <keras.layers.core.Activation object at 0x23e8bf5f8>
# <keras.layers.convolutional.Conv2D object at 0x23e9a3048>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 0.8390
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 6.691412636457029 0.1036981451431897 PL
# <keras.layers.convolutional.Conv2D object at 0x23e8acf60>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 0.8924
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.0268901605407725 0.12201279304054868 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e98f5f8>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23e897400>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23e985c18>
# <keras.layers.core.Activation object at 0x23e858978>
# <keras.layers.merge.Concatenate object at 0x23e8453c8>
# <keras.layers.convolutional.Conv2D object at 0x23e845940>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 1.5056
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 6.1432959398166185 0.08314036015300019 PL
# <keras.layers.core.Lambda object at 0x23e8315f8>
# <keras.layers.core.Activation object at 0x23e7de208>
# <keras.layers.convolutional.Conv2D object at 0x23e7be9e8>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 1.6816
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.0790300251977625 0.08174355500286146 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e7ac4e0>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x23e76c080>
# <keras.layers.convolutional.Conv2D object at 0x23e75a6d8>
# (1, 3, 192, 224)
# (576, 224)
# % spikes outside bulk 0.00
# % sigma 0.9065
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.587275905508366 0.1002436822358127 LOG_N
# <keras.layers.normalization.BatchNormalization object at 0x23e739dd8>
# (224,)
# (1, 224)
# <keras.layers.core.Activation object at 0x23e6ee208>
# <keras.layers.convolutional.Conv2D object at 0x23e7e8048>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 0.8102
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 8.003259018618419 0.07958795725016232 PL
# <keras.layers.convolutional.Conv2D object at 0x23e6e52b0>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 1.0798
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.602836723123869 0.11031307467050189 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e7d4ba8>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23e6d2160>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23e7bed30>
# <keras.layers.core.Activation object at 0x23e695710>
# <keras.layers.merge.Concatenate object at 0x23e680630>
# <keras.layers.convolutional.Conv2D object at 0x23e680cf8>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 1.8511
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.626117204950174 0.07722653512030997 PL
# <keras.layers.core.Lambda object at 0x23e62f198>
# <keras.layers.core.Activation object at 0x23e619518>
# <keras.layers.convolutional.Conv2D object at 0x23e5dd048>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 1.4815
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.76291660836998 0.06276941890699322 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e5fa7b8>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x23e5a9400>
# <keras.layers.convolutional.Conv2D object at 0x23e593a58>
# (1, 3, 192, 224)
# (576, 224)
# % spikes outside bulk 0.00
# % sigma 1.3344
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.008556718487917 0.08433355794962383 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e541c50>
# (224,)
# (1, 224)
# <keras.layers.core.Activation object at 0x23e536ef0>
# <keras.layers.convolutional.Conv2D object at 0x23e624ba8>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 0.8367
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 8.068916221247694 0.05887122324070865 PL
# <keras.layers.convolutional.Conv2D object at 0x23e52b438>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 1.4379
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 2.835398516174445 0.06177016819789688 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e60f240>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23e50fd30>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23e604240>
# <keras.layers.core.Activation object at 0x23e4d2860>
# <keras.layers.merge.Concatenate object at 0x23e4ba9b0>
# <keras.layers.convolutional.Conv2D object at 0x23e4baf98>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 3.6003
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.1006917850396674 0.035795441033122266 PL
# <keras.layers.core.Lambda object at 0x23e469eb8>
# <keras.layers.core.Activation object at 0x23e455ef0>
# <keras.layers.convolutional.Conv2D object at 0x23e436278>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 1.2036
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 6.755929074199959 0.08647337628160406 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e4209b0>
# (192,)
# (1, 192)
# <keras.layers.core.Activation object at 0x23e3e2668>
# <keras.layers.convolutional.Conv2D object at 0x23e3ced68>
# (1, 3, 192, 224)
# (576, 224)
# % spikes outside bulk 0.00
# % sigma 0.9453
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.772127583728522 0.07116381034434538 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e3bb2b0>
# (224,)
# (1, 224)
# <keras.layers.core.Activation object at 0x23e37d828>
# <keras.layers.convolutional.Conv2D object at 0x23e460e80>
# (1, 1, 2080, 192)
# (2080, 192)
# % spikes outside bulk 0.00
# % sigma 1.7269
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.129818766370996 0.07585079877947154 PL
# <keras.layers.convolutional.Conv2D object at 0x23e353080>
# (3, 1, 224, 256)
# (672, 256)
# % spikes outside bulk 0.00
# % sigma 1.5979
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 2.7876370874457415 0.06994977724347273 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e44a278>
# (192,)
# (1, 192)
# <keras.layers.normalization.BatchNormalization object at 0x23e367860>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x23e43f128>
# <keras.layers.core.Activation object at 0x23e3011d0>
# <keras.layers.merge.Concatenate object at 0x23e2f5668>
# <keras.layers.convolutional.Conv2D object at 0x23e2f5ac8>
# (1, 1, 448, 2080)
# (448, 2080)
# % spikes outside bulk 0.00
# % sigma 1.5237
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 3.386896499332305 0.05873587427946747 PL
# <keras.layers.core.Lambda object at 0x23e2e2ac8>
# <keras.layers.convolutional.Conv2D object at 0x23e28fb00>
# (1, 1, 2080, 1536)
# (2080, 1536)
# % spikes outside bulk 0.00
# % sigma 1.2538
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 11.928971160773743 0.06283998533622503 PL
# <keras.layers.normalization.BatchNormalization object at 0x23e285128>
# (1536,)
# (1, 1536)
# <keras.layers.core.Activation object at 0x23e27cef0>
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x23e265048>
# <keras.layers.core.Dense object at 0x23e27c198>
# (1536, 1000)
# (1536, 1000)
# % spikes outside bulk 0.00
# % sigma 2.9669
# Calculating best minimal value for power law fit
# 4.169739765192654 0.027713342353483106 PL
# Assuming nested distributions

# %%
print(len(alphas))
plt.hist(alphas,bins=50);
plt.title("power law fits, InceptionResNetV2")
# Out:
# 192
# Text(0.5,1,'power law fits, InceptionResNetV2')

# %%
for kmodel in [mobilenet.MobileNet]:
    kmodel(weights=None)
    model = kmodel(weights='imagenet')
    alphas = analyze_model(model)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 7s 0us/step
# <keras.engine.topology.InputLayer object at 0x2fbd267f0>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fbd260b8>
# <keras.layers.convolutional.Conv2D object at 0x2fbd109b0>
# (3, 3, 3, 32)
# (27, 32)
# <keras.layers.normalization.BatchNormalization object at 0x2fbd10518>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x2fbd07e80>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fbcf3a58>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fbd077f0>
# (3, 3, 32, 1)
# (32, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2fbcd4898>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x2fbca2128>
# <keras.layers.convolutional.Conv2D object at 0x2fbc8a630>
# (1, 1, 32, 64)
# (32, 64)
# <keras.layers.normalization.BatchNormalization object at 0x2fbc38588>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2fbc26c50>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fbc12438>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fbc26400>
# (3, 3, 64, 1)
# (64, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2fbbf26d8>
# (64,)
# (1, 64)
# <keras.layers.core.Activation object at 0x2fbbca2e8>
# <keras.layers.convolutional.Conv2D object at 0x2fbbb3b00>
# (1, 1, 64, 128)
# (64, 128)
# RMT_Util.ipynb:7: RuntimeWarning: divide by zero encountered in true_divide
#   "## RMT Util\n",
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in sqrt
#   "## RMT Util\n",
# % spikes outside bulk 0.00
# % sigma 1.6828
# Calculating best minimal value for power law fit
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Assuming nested distributions
# 2.071537445133694 0.17692378813161624 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2fbb62128>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2fbb43710>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fbb24438>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fbb43f98>
# (3, 3, 128, 1)
# (128, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2fbb0d0f0>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2fba8c438>
# <keras.layers.convolutional.Conv2D object at 0x2fbab3f28>
# (1, 1, 128, 128)
# (128, 128)
# % spikes outside bulk 0.00
# % sigma 1.5480
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in multiply
#   "## RMT Util\n",
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.5760734936616245 0.1671158332240411 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2d84036d8>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2d8417978>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2ddd73dd8>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2d8417b70>
# (3, 3, 128, 1)
# (128, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2f70bdf60>
# (128,)
# (1, 128)
# <keras.layers.core.Activation object at 0x2f965eba8>
# <keras.layers.convolutional.Conv2D object at 0x2f96594e0>
# (1, 1, 128, 256)
# (128, 256)
# % spikes outside bulk 0.00
# % sigma 1.6069
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.145173038237588 0.16893552950306667 TPL
# <keras.layers.normalization.BatchNormalization object at 0x2fab80c88>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x2fb5a9470>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fb5bee10>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fb5a9b70>
# (3, 3, 256, 1)
# (256, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2f8177550>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x30b2cbcf8>
# <keras.layers.convolutional.Conv2D object at 0x30b778dd8>
# (1, 1, 256, 256)
# (256, 256)
# % spikes outside bulk 0.00
# % sigma 1.5937
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.9951163798484335 0.12927765555181026 PL
# <keras.layers.normalization.BatchNormalization object at 0x3c89de780>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x3c89d8ef0>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2faef9908>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x3c8aed668>
# (3, 3, 256, 1)
# (256, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2faef7f28>
# (256,)
# (1, 256)
# <keras.layers.core.Activation object at 0x30ba0ea90>
# <keras.layers.convolutional.Conv2D object at 0x30b9fbc88>
# (1, 1, 256, 512)
# (256, 512)
# % spikes outside bulk 0.00
# % sigma 1.7115
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.4612685224091 0.1548729907566031 TPL
# <keras.layers.normalization.BatchNormalization object at 0x30bfe1278>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x30c06ba20>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2f929e400>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x30c06bf60>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2dddf1ac8>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fb8bec50>
# <keras.layers.convolutional.Conv2D object at 0x30ab42588>
# (1, 1, 512, 512)
# (512, 512)
# % spikes outside bulk 0.00
# % sigma 1.6249
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.358953805677931 0.06855536767702275 PL
# <keras.layers.normalization.BatchNormalization object at 0x30531fd30>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fa3f2518>
# <keras.layers.convolutional.ZeroPadding2D object at 0x30afb6e10>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fa3f2c18>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x30aa61438>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x30b3e5da0>
# <keras.layers.convolutional.Conv2D object at 0x30b36c710>
# (1, 1, 512, 512)
# (512, 512)
# % spikes outside bulk 0.00
# % sigma 1.6208
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.862248187543874 0.08156718328894508 PL
# <keras.layers.normalization.BatchNormalization object at 0x2fb3b5828>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2f9634f98>
# <keras.layers.convolutional.ZeroPadding2D object at 0x30b4a1fd0>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2f9603710>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x30b43c3c8>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fb96eb38>
# <keras.layers.convolutional.Conv2D object at 0x2fb95bd30>
# (1, 1, 512, 512)
# (512, 512)
# % spikes outside bulk 0.00
# % sigma 1.6603
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.538080305052347 0.07312595845949044 PL
# <keras.layers.normalization.BatchNormalization object at 0x2fa560320>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fa568c50>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2faecf4a8>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fa5801d0>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2f8f63b70>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fb6d9cf8>
# <keras.layers.convolutional.Conv2D object at 0x2fb6e1630>
# (1, 1, 512, 512)
# (512, 512)
# % spikes outside bulk 0.00
# % sigma 1.9744
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.121040400410127 0.0562585487275753 PL
# <keras.layers.normalization.BatchNormalization object at 0x302de0dd8>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x3052925c0>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fb245eb8>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x305292cc0>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2f6f01ba8>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2de298e48>
# <keras.layers.convolutional.Conv2D object at 0x2fb8a37b8>
# (1, 1, 512, 512)
# (512, 512)
# % spikes outside bulk 0.00
# % sigma 2.6328
# Calculating best minimal value for power law fit
# Assuming nested distributions
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:1602: RuntimeWarning: invalid value encountered in true_divide
#   CDF = CDF/norm
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# 4.14836323201193 0.03319655616924516 PL
# <keras.layers.normalization.BatchNormalization object at 0x2fb46b8d0>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2fa9ae0b8>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2fa9c4a58>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2fa9ae7b8>
# (3, 3, 512, 1)
# (512, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2fa8b8198>
# (512,)
# (1, 512)
# <keras.layers.core.Activation object at 0x2faac6be0>
# <keras.layers.convolutional.Conv2D object at 0x2dd5dfdd8>
# (1, 1, 512, 1024)
# (512, 1024)
# % spikes outside bulk 0.00
# % sigma 2.8929
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.409836571463762 0.037710576876857416 PL
# <keras.layers.normalization.BatchNormalization object at 0x2fae023c8>
# (1024,)
# (1, 1024)
# <keras.layers.core.Activation object at 0x2fae19cf8>
# <keras.layers.convolutional.ZeroPadding2D object at 0x2f9228550>
# <keras.layers.convolutional.DepthwiseConv2D object at 0x2f942a198>
# (3, 3, 1024, 1)
# (1024, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2f938d048>
# (1024,)
# (1, 1024)
# <keras.layers.core.Activation object at 0x2f8ddce80>
# <keras.layers.convolutional.Conv2D object at 0x2f8dd37b8>
# (1, 1, 1024, 1024)
# (1024, 1024)
# % spikes outside bulk 0.00
# % sigma 2.2302
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.983165599108411 0.03479342336580102 PL
# <keras.layers.normalization.BatchNormalization object at 0x2f84ee080>
# (1024,)
# (1, 1024)
# <keras.layers.core.Activation object at 0x2f94d0828>
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x2dd5a2d30>
# <keras.layers.core.Reshape object at 0x2f96b9400>
# <keras.layers.core.Dropout object at 0x2f94d0f28>
# <keras.layers.convolutional.Conv2D object at 0x2dd8346a0>
# (1, 1, 1024, 1000)
# (1024, 1000)
# % spikes outside bulk 0.00
# % sigma 4.8940
# Calculating best minimal value for power law fit
# 4.135716116936736 0.024112659879542586 PL
# <keras.layers.core.Activation object at 0x2f977b780>
# <keras.layers.core.Reshape object at 0x2f976dac8>
# Assuming nested distributions

# %%
print(len(alphas))
plt.hist(alphas,bins=30);
plt.title("power law fits, MobileNet")
# Out:
# 13
# Text(0.5,1,'power law fits, MobileNet')

# %%
for kmodel in [nasnet.NASNetLarge]:
    kmodel(weights=None)
    model = kmodel(weights='imagenet')
    alphas = analyze_model(model)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.8/NASNet-large.h5
# 359751680/359746192 [==============================] - 161s 0us/step
# <keras.engine.topology.InputLayer object at 0x30159c668>
# <keras.layers.convolutional.Conv2D object at 0x3016b5d30>
# (3, 3, 3, 96)
# (27, 96)
# <keras.layers.normalization.BatchNormalization object at 0x3016b5b00>
# (96,)
# (1, 96)
# <keras.layers.core.Activation object at 0x30181bcc0>
# <keras.layers.convolutional.Conv2D object at 0x3017bf048>
# (1, 1, 96, 42)
# (96, 42)
# <keras.layers.normalization.BatchNormalization object at 0x30181bac8>
# (42,)
# (1, 42)
# <keras.layers.core.Activation object at 0x301757ac8>
# <keras.layers.core.Activation object at 0x3016f96d8>
# <keras.layers.convolutional.SeparableConv2D object at 0x3016e72b0>
# (5, 5, 42, 1)
# (42, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3018475f8>
# (7, 7, 96, 1)
# (96, 49)
# <keras.layers.normalization.BatchNormalization object at 0x30173a438>
# (42,)
# (1, 42)
# <keras.layers.normalization.BatchNormalization object at 0x301963048>
# (42,)
# (1, 42)
# <keras.layers.core.Activation object at 0x30173a4a8>
# <keras.layers.core.Activation object at 0x301927ef0>
# <keras.layers.convolutional.SeparableConv2D object at 0x30172f3c8>
# (5, 5, 42, 1)
# (42, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x30191c128>
# (7, 7, 42, 1)
# (42, 49)
# <keras.layers.normalization.BatchNormalization object at 0x30170f320>
# (42,)
# (1, 42)
# <keras.layers.normalization.BatchNormalization object at 0x3018cb9e8>
# (42,)
# (1, 42)
# <keras.layers.core.Activation object at 0x3018300b8>
# <keras.layers.merge.Add object at 0x301796160>
# <keras.layers.convolutional.SeparableConv2D object at 0x301ace390>
# (7, 7, 96, 1)
# (96, 49)
# <keras.layers.core.Activation object at 0x301a354e0>
# <keras.layers.core.Activation object at 0x301bc7128>
# <keras.layers.normalization.BatchNormalization object at 0x301ae3d30>
# (42,)
# (1, 42)
# <keras.layers.convolutional.SeparableConv2D object at 0x3019eb9b0>
# (5, 5, 96, 1)
# (96, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x301baf358>
# (3, 3, 42, 1)
# (42, 9)
# <keras.layers.core.Activation object at 0x301abbe10>
# <keras.layers.normalization.BatchNormalization object at 0x301aec4a8>
# (42,)
# (1, 42)
# <keras.layers.normalization.BatchNormalization object at 0x301ba59e8>
# (42,)
# (1, 42)
# <keras.layers.convolutional.SeparableConv2D object at 0x301a9ce10>
# (7, 7, 42, 1)
# (42, 49)
# <keras.layers.core.Activation object at 0x3019d80f0>
# <keras.layers.core.Activation object at 0x301ba5710>
# <keras.layers.pooling.MaxPooling2D object at 0x3018b62b0>
# <keras.layers.normalization.BatchNormalization object at 0x301a49710>
# (42,)
# (1, 42)
# <keras.layers.convolutional.SeparableConv2D object at 0x3019ae358>
# (5, 5, 42, 1)
# (42, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x301b7c358>
# (3, 3, 42, 1)
# (42, 9)
# <keras.layers.core.Activation object at 0x301c7e630>
# <keras.layers.merge.Add object at 0x3018a06a0>
# <keras.layers.pooling.AveragePooling2D object at 0x3019ccb00>
# <keras.layers.normalization.BatchNormalization object at 0x301c4a940>
# (42,)
# (1, 42)
# <keras.layers.pooling.AveragePooling2D object at 0x301b0c080>
# <keras.layers.normalization.BatchNormalization object at 0x301c2f6d8>
# (42,)
# (1, 42)
# <keras.layers.pooling.MaxPooling2D object at 0x301c04160>
# <keras.layers.convolutional.ZeroPadding2D object at 0x301d6dc18>
# <keras.layers.merge.Add object at 0x3019b82b0>
# <keras.layers.merge.Add object at 0x301c21358>
# <keras.layers.merge.Add object at 0x301c36c50>
# <keras.layers.convolutional.Cropping2D object at 0x301d6d898>
# <keras.layers.merge.Concatenate object at 0x3017b57f0>
# <keras.layers.pooling.AveragePooling2D object at 0x301b3fb00>
# <keras.layers.pooling.AveragePooling2D object at 0x301d6da58>
# <keras.layers.core.Activation object at 0x3017a1c88>
# <keras.layers.convolutional.Conv2D object at 0x301d82780>
# (1, 1, 96, 42)
# (96, 42)
# <keras.layers.convolutional.Conv2D object at 0x301d61278>
# (1, 1, 96, 42)
# (96, 42)
# <keras.layers.convolutional.Conv2D object at 0x3017a1048>
# (1, 1, 168, 84)
# (168, 84)
# RMT_Util.ipynb:7: RuntimeWarning: divide by zero encountered in true_divide
#   "## RMT Util\n",
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in sqrt
#   "## RMT Util\n",
# % spikes outside bulk 0.00
# % sigma 1.9862
# Calculating best minimal value for power law fit
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Assuming nested distributions
# 3.240188386684803 0.14585838009378688 PL
# <keras.layers.merge.Concatenate object at 0x301d59438>
# <keras.layers.normalization.BatchNormalization object at 0x301d4d748>
# (84,)
# (1, 84)
# <keras.layers.normalization.BatchNormalization object at 0x301d595f8>
# (84,)
# (1, 84)
# <keras.layers.core.Activation object at 0x301cb4b38>
# <keras.layers.core.Activation object at 0x301ed4630>
# <keras.layers.convolutional.SeparableConv2D object at 0x301c609b0>
# (5, 5, 84, 1)
# (84, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x301ea10f0>
# (7, 7, 84, 1)
# (84, 49)
# <keras.layers.normalization.BatchNormalization object at 0x301e12c50>
# (84,)
# (1, 84)
# <keras.layers.normalization.BatchNormalization object at 0x301e77898>
# (84,)
# (1, 84)
# <keras.layers.core.Activation object at 0x301e12ef0>
# <keras.layers.core.Activation object at 0x301e652e8>
# <keras.layers.convolutional.SeparableConv2D object at 0x301e07cf8>
# (5, 5, 84, 1)
# (84, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x301e5b668>
# (7, 7, 84, 1)
# (84, 49)
# <keras.layers.normalization.BatchNormalization object at 0x301ee0780>
# (84,)
# (1, 84)
# <keras.layers.normalization.BatchNormalization object at 0x301dc8828>
# (84,)
# (1, 84)
# <keras.layers.core.Activation object at 0x302028898>
# <keras.layers.merge.Add object at 0x301cdccc0>
# <keras.layers.convolutional.SeparableConv2D object at 0x301f50f28>
# (7, 7, 84, 1)
# (84, 49)
# <keras.layers.core.Activation object at 0x3020af080>
# <keras.layers.core.Activation object at 0x302117908>
# <keras.layers.normalization.BatchNormalization object at 0x30200dcf8>
# (84,)
# (1, 84)
# <keras.layers.convolutional.SeparableConv2D object at 0x3021f80f0>
# (5, 5, 84, 1)
# (84, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3021eeb70>
# (3, 3, 84, 1)
# (84, 9)
# <keras.layers.core.Activation object at 0x30200d8d0>
# <keras.layers.normalization.BatchNormalization object at 0x3020eed68>
# (84,)
# (1, 84)
# <keras.layers.normalization.BatchNormalization object at 0x3021ee390>
# (84,)
# (1, 84)
# <keras.layers.convolutional.SeparableConv2D object at 0x301f915f8>
# (7, 7, 84, 1)
# (84, 49)
# <keras.layers.core.Activation object at 0x3020d1710>
# <keras.layers.core.Activation object at 0x3021ee358>
# <keras.layers.pooling.MaxPooling2D object at 0x301e3b400>
# <keras.layers.normalization.BatchNormalization object at 0x30201d080>
# (84,)
# (1, 84)
# <keras.layers.convolutional.SeparableConv2D object at 0x3021dcfd0>
# (5, 5, 84, 1)
# (84, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3020f8d68>
# (3, 3, 84, 1)
# (84, 9)
# <keras.layers.core.Activation object at 0x302319940>
# <keras.layers.merge.Add object at 0x301f85080>
# <keras.layers.pooling.AveragePooling2D object at 0x301fccba8>
# <keras.layers.normalization.BatchNormalization object at 0x30217c978>
# (84,)
# (1, 84)
# <keras.layers.pooling.AveragePooling2D object at 0x302161ba8>
# <keras.layers.normalization.BatchNormalization object at 0x30234c940>
# (84,)
# (1, 84)
# <keras.layers.pooling.MaxPooling2D object at 0x30214ab38>
# <keras.layers.convolutional.ZeroPadding2D object at 0x3022b3160>
# <keras.layers.merge.Add object at 0x301fc3518>
# <keras.layers.merge.Add object at 0x3020c4780>
# <keras.layers.merge.Add object at 0x302332198>
# <keras.layers.convolutional.Cropping2D object at 0x3022b3f60>
# <keras.layers.merge.Concatenate object at 0x301cf9550>
# <keras.layers.pooling.AveragePooling2D object at 0x3022be080>
# <keras.layers.pooling.AveragePooling2D object at 0x3022b3dd8>
# <keras.layers.convolutional.Conv2D object at 0x3022be048>
# (1, 1, 168, 84)
# (168, 84)
# % spikes outside bulk 0.00
# % sigma 2.3128
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.819042308628136 0.16319760297655195 TPL
# <keras.layers.convolutional.Conv2D object at 0x3022392b0>
# (1, 1, 168, 84)
# (168, 84)
# % spikes outside bulk 0.00
# % sigma 1.4654
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.177728424865701 0.19326884060818972 PL
# <keras.layers.core.Activation object at 0x301c6b438>
# <keras.layers.merge.Concatenate object at 0x3022a8b00>
# <keras.layers.convolutional.Conv2D object at 0x301cf0d68>
# (1, 1, 336, 168)
# (336, 168)
# % spikes outside bulk 0.00
# % sigma 1.5421
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8767798780546037 0.18000191716062408 TPL
# <keras.layers.normalization.BatchNormalization object at 0x3022a8f60>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3022a0518>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3024b8e10>
# <keras.layers.core.Activation object at 0x302427ef0>
# <keras.layers.core.Activation object at 0x3025ba518>
# <keras.layers.core.Activation object at 0x3027d2908>
# <keras.layers.core.Activation object at 0x302819e48>
# <keras.layers.convolutional.SeparableConv2D object at 0x3024acd30>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x30241c0b8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3025a4320>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x302794668>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x302819208>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x302499e10>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3023de9e8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x302533630>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x30274c8d0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3029242e8>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x302499978>
# <keras.layers.core.Activation object at 0x302397be0>
# <keras.layers.core.Activation object at 0x30251eda0>
# <keras.layers.core.Activation object at 0x302737c88>
# <keras.layers.core.Activation object at 0x302924978>
# <keras.layers.convolutional.SeparableConv2D object at 0x30248e128>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x302653d68>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x30255b198>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x302718160>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x30293bac8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x30243c2e8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3025ec160>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3027c76d8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3026a4c88>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x30269b470>
# <keras.layers.pooling.AveragePooling2D object at 0x3026c5198>
# <keras.layers.pooling.AveragePooling2D object at 0x302805208>
# <keras.layers.normalization.BatchNormalization object at 0x3028a1748>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x30238c240>
# <keras.layers.merge.Add object at 0x3025d4860>
# <keras.layers.merge.Add object at 0x3026ef4e0>
# <keras.layers.merge.Add object at 0x302819da0>
# <keras.layers.merge.Add object at 0x302819748>
# <keras.layers.merge.Concatenate object at 0x302273828>
# <keras.layers.core.Activation object at 0x3028f1cc0>
# <keras.layers.core.Activation object at 0x30221a400>
# <keras.layers.convolutional.Conv2D object at 0x3028f1860>
# (1, 1, 336, 168)
# (336, 168)
# % spikes outside bulk 0.00
# % sigma 1.7461
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.56065355610692 0.14852061013634188 TPL
# <keras.layers.convolutional.Conv2D object at 0x30237f5f8>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.1547
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7863126229769888 0.1510299933501309 TPL
# <keras.layers.normalization.BatchNormalization object at 0x302875550>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x30282cb38>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x302943b38>
# <keras.layers.core.Activation object at 0x2fcbd3b70>
# <keras.layers.core.Activation object at 0x2fe532eb8>
# <keras.layers.core.Activation object at 0x2ffa773c8>
# <keras.layers.core.Activation object at 0x301c74dd8>
# <keras.layers.convolutional.SeparableConv2D object at 0x2d63a4cc0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x2fccf8978>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x2fe532128>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x2ffbc01d0>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x301c9deb8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2d6b89b00>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x2fd5b2da0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x2fef0fd68>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3002d9e48>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x301c9d400>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x2dd46ce80>
# <keras.layers.core.Activation object at 0x2fd8994e0>
# <keras.layers.core.Activation object at 0x2fef0fa90>
# <keras.layers.core.Activation object at 0x300455898>
# <keras.layers.core.Activation object at 0x301de8438>
# <keras.layers.convolutional.SeparableConv2D object at 0x2d5edfe10>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x2fd864198>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x2ff06ec88>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3005e6b70>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x301f3ec18>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x2fc9c75f8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x2fe3cb470>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x2ff92dd68>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x300d26b38>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x300fce390>
# <keras.layers.pooling.AveragePooling2D object at 0x30184e6a0>
# <keras.layers.pooling.AveragePooling2D object at 0x301999d68>
# <keras.layers.normalization.BatchNormalization object at 0x3027fab00>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x23e20ada0>
# <keras.layers.merge.Add object at 0x2fe3ada20>
# <keras.layers.merge.Add object at 0x3012bf048>
# <keras.layers.merge.Add object at 0x301c74128>
# <keras.layers.merge.Add object at 0x301c74908>
# <keras.layers.merge.Concatenate object at 0x240fba550>
# <keras.layers.core.Activation object at 0x3e1a30fd0>
# <keras.layers.core.Activation object at 0x23e18f940>
# <keras.layers.convolutional.Conv2D object at 0x3e1a30f28>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.8411
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7244848651673585 0.13119716435457518 TPL
# <keras.layers.convolutional.Conv2D object at 0x2dd453da0>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.2298
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7550767899805872 0.13813683388336323 TPL
# <keras.layers.normalization.BatchNormalization object at 0x3e1af0ac8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e1b41208>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e1ce5d68>
# <keras.layers.core.Activation object at 0x3e20bf320>
# <keras.layers.core.Activation object at 0x3e2353f60>
# <keras.layers.core.Activation object at 0x3e25cd630>
# <keras.layers.core.Activation object at 0x3e29a69b0>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e1f2eef0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e20d4d68>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e239b5c0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e25e4940>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e29a6908>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e1f804a8>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e21c7f60>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e247aef0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e26d2ef0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e29b6160>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e1f6beb8>
# <keras.layers.core.Activation object at 0x3e21fd748>
# <keras.layers.core.Activation object at 0x3e2492208>
# <keras.layers.core.Activation object at 0x3e2709a58>
# <keras.layers.core.Activation object at 0x3e29b6438>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e1f95940>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e2244cc0>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e24a6c50>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e2721e48>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e29cbe80>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e208bb38>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e22fce10>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e2597e48>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e28326d8>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x3e284de80>
# <keras.layers.pooling.AveragePooling2D object at 0x3e29071d0>
# <keras.layers.pooling.AveragePooling2D object at 0x3e296db00>
# <keras.layers.normalization.BatchNormalization object at 0x3e2ab7cf8>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x3e1c7de10>
# <keras.layers.merge.Add object at 0x3e233bb70>
# <keras.layers.merge.Add object at 0x3e287b908>
# <keras.layers.merge.Add object at 0x3e29a62e8>
# <keras.layers.merge.Add object at 0x3e29a6748>
# <keras.layers.merge.Concatenate object at 0x3e1c4af60>
# <keras.layers.core.Activation object at 0x3e2b532b0>
# <keras.layers.core.Activation object at 0x3e1c35390>
# <keras.layers.convolutional.Conv2D object at 0x3e2b53438>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.4008
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7366304311949379 0.13055108012475275 TPL
# <keras.layers.convolutional.Conv2D object at 0x3e1c68be0>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.4090
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.7620620393457584 0.11290896043611653 TPL
# <keras.layers.normalization.BatchNormalization object at 0x3e2bf0e10>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e2c4b630>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e2e135f8>
# <keras.layers.core.Activation object at 0x3e2fc2668>
# <keras.layers.core.Activation object at 0x3e326d940>
# <keras.layers.core.Activation object at 0x3e34d1978>
# <keras.layers.core.Activation object at 0x3e38a9cf8>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e2e54278>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e2fda978>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e32a1908>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e34eed68>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e38a9c50>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e2e6ee48>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e30c3f28>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3399278>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e35cef60>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e38b84a8>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e2e88240>
# <keras.layers.core.Activation object at 0x3e30fea90>
# <keras.layers.core.Activation object at 0x3e3399550>
# <keras.layers.core.Activation object at 0x3e362b390>
# <keras.layers.core.Activation object at 0x3e38b8780>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e2e99c88>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e3116e80>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e33adf98>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e36486d8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e38fecf8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e2f8ae80>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3226710>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3497e10>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3737a20>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x3e376c208>
# <keras.layers.pooling.AveragePooling2D object at 0x3e384beb8>
# <keras.layers.pooling.AveragePooling2D object at 0x3e3870e48>
# <keras.layers.normalization.BatchNormalization object at 0x3e39b9e48>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x3e2d9e6d8>
# <keras.layers.merge.Add object at 0x3e323feb8>
# <keras.layers.merge.Add object at 0x3e3782c50>
# <keras.layers.merge.Add object at 0x3e38a9630>
# <keras.layers.merge.Add object at 0x3e38a9a90>
# <keras.layers.merge.Concatenate object at 0x3e2d386d8>
# <keras.layers.core.Activation object at 0x3e3a5b550>
# <keras.layers.core.Activation object at 0x3e39fcba8>
# <keras.layers.convolutional.Conv2D object at 0x3e3a5b780>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.6808
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.8244151103233628 0.1462967931805021 TPL
# <keras.layers.convolutional.Conv2D object at 0x3e3a10eb8>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.5172
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.402291525350813 0.13274749178453743 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e3b37f60>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3b52978>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e3d16940>
# <keras.layers.core.Activation object at 0x3e3ecd9b0>
# <keras.layers.core.Activation object at 0x3e417cc88>
# <keras.layers.core.Activation object at 0x3e43e1cc0>
# <keras.layers.core.Activation object at 0x3e47b3c18>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e3d5d5c0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e3ee5da0>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e41abc50>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e43f8eb8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e47b3f98>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e3d911d0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e3ff5630>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e42a15c0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e4506940>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e47cd7f0>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e3d91588>
# <keras.layers.core.Activation object at 0x3e40263c8>
# <keras.layers.core.Activation object at 0x3e42a1898>
# <keras.layers.core.Activation object at 0x3e453a128>
# <keras.layers.core.Activation object at 0x3e47cdac8>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e3da9fd0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e4041710>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e42e7e10>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e454fb70>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e47deeb8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e3e93e48>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e4132a58>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e43a6f60>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e4640d68>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x3e4678550>
# <keras.layers.pooling.AveragePooling2D object at 0x3e475a438>
# <keras.layers.pooling.AveragePooling2D object at 0x3e477de10>
# <keras.layers.normalization.BatchNormalization object at 0x3e48ef748>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x3e3ca5a20>
# <keras.layers.merge.Add object at 0x3e4167240>
# <keras.layers.merge.Add object at 0x3e4690f98>
# <keras.layers.merge.Add object at 0x3e47b3978>
# <keras.layers.merge.Add object at 0x3e47b3dd8>
# <keras.layers.merge.Concatenate object at 0x3e3c3da20>
# <keras.layers.core.Activation object at 0x3e4962898>
# <keras.layers.core.Activation object at 0x3e4903ef0>
# <keras.layers.convolutional.Conv2D object at 0x3e4962ac8>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.4832
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.762809759774156 0.111584332489428 PL
# <keras.layers.convolutional.Conv2D object at 0x3e4932978>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.4689
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6774500945330217 0.10624914594894003 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e4a264e0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e4a60cc0>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e4c20c88>
# <keras.layers.core.Activation object at 0x3e4ddacf8>
# <keras.layers.core.Activation object at 0x3e508bfd0>
# <keras.layers.core.Activation object at 0x3e530a048>
# <keras.layers.core.Activation object at 0x3e56de3c8>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e4c6a908>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e4df3f98>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e50b7ef0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e531ea90>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e56de2e8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e4c9e518>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e4eff978>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e51ac908>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e540fc88>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e56deb38>
# (168,)
# (1, 168)
# <keras.layers.core.Activation object at 0x3e4c9e8d0>
# <keras.layers.core.Activation object at 0x3e4f35160>
# <keras.layers.core.Activation object at 0x3e51acbe0>
# <keras.layers.core.Activation object at 0x3e5447470>
# <keras.layers.core.Activation object at 0x3e56dee10>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e4ce4da0>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e4f49ba8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e51cbe48>
# (5, 5, 168, 1)
# (168, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e545deb8>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e5703898>
# (3, 3, 168, 1)
# (168, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e4d9efd0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e5038da0>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e52da860>
# (168,)
# (1, 168)
# <keras.layers.normalization.BatchNormalization object at 0x3e554ed30>
# (168,)
# (1, 168)
# <keras.layers.pooling.AveragePooling2D object at 0x3e5584898>
# <keras.layers.pooling.AveragePooling2D object at 0x3e563dcc0>
# <keras.layers.pooling.AveragePooling2D object at 0x3e5684f60>
# <keras.layers.normalization.BatchNormalization object at 0x3e57f1a90>
# (168,)
# (1, 168)
# <keras.layers.merge.Add object at 0x3e4bb3d68>
# <keras.layers.merge.Add object at 0x3e5071588>
# <keras.layers.merge.Add object at 0x3e55e92e8>
# <keras.layers.merge.Add object at 0x3e56c6cc0>
# <keras.layers.merge.Add object at 0x3e56de240>
# <keras.layers.merge.Concatenate object at 0x3e4b69128>
# <keras.layers.core.Activation object at 0x3e582c278>
# <keras.layers.core.Activation object at 0x3e586fbe0>
# <keras.layers.convolutional.Conv2D object at 0x3e5841cc0>
# (1, 1, 1008, 336)
# (1008, 336)
# % spikes outside bulk 0.00
# % sigma 3.1891
# Calculating best minimal value for power law fit
# Assuming nested distributions
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:1602: RuntimeWarning: invalid value encountered in true_divide
#   CDF = CDF/norm
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# 4.333493640604175 0.07189999580885775 PL
# <keras.layers.convolutional.Conv2D object at 0x3e586fe10>
# (1, 1, 1008, 336)
# (1008, 336)
# % spikes outside bulk 0.00
# % sigma 2.0206
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.692997946090563 0.09987433998174444 TPL
# <keras.layers.normalization.BatchNormalization object at 0x3e5966e80>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e5930828>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e5b29fd0>
# <keras.layers.core.Activation object at 0x3e5d0b080>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e5b73c50>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e5d1fac8>
# (7, 7, 336, 1)
# (336, 49)
# <keras.layers.normalization.BatchNormalization object at 0x3e5bac860>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e5e13cc0>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e5bacc18>
# <keras.layers.core.Activation object at 0x3e5e4e4a8>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e5bc4e10>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e5e65ef0>
# (7, 7, 336, 1)
# (336, 49)
# <keras.layers.normalization.BatchNormalization object at 0x3e5cd8898>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e5f54d68>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e6047cf8>
# <keras.layers.merge.Add object at 0x3e5ab9c18>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6092e80>
# (7, 7, 336, 1)
# (336, 49)
# <keras.layers.core.Activation object at 0x3e62e4b38>
# <keras.layers.core.Activation object at 0x3e65cda58>
# <keras.layers.normalization.BatchNormalization object at 0x3e60cffd0>
# (336,)
# (1, 336)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e632fcc0>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e660a9e8>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.core.Activation object at 0x3e60ec2e8>
# <keras.layers.normalization.BatchNormalization object at 0x3e636de10>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e660aeb8>
# (336,)
# (1, 336)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e60ffd30>
# (7, 7, 336, 1)
# (336, 49)
# <keras.layers.core.Activation object at 0x3e6382128>
# <keras.layers.core.Activation object at 0x3e66201d0>
# <keras.layers.pooling.MaxPooling2D object at 0x3e5f8c8d0>
# <keras.layers.normalization.BatchNormalization object at 0x3e61f2f28>
# (336,)
# (1, 336)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e639ab70>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6635c18>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.core.Activation object at 0x3e688d240>
# <keras.layers.merge.Add object at 0x3e5ff4320>
# <keras.layers.pooling.AveragePooling2D object at 0x3e622c710>
# <keras.layers.normalization.BatchNormalization object at 0x3e648bd68>
# (336,)
# (1, 336)
# <keras.layers.pooling.AveragePooling2D object at 0x3e64c0550>
# <keras.layers.normalization.BatchNormalization object at 0x3e6728e10>
# (336,)
# (1, 336)
# <keras.layers.pooling.MaxPooling2D object at 0x3e650ceb8>
# <keras.layers.convolutional.ZeroPadding2D object at 0x3e68a4e10>
# <keras.layers.merge.Add object at 0x3e6292160>
# <keras.layers.merge.Add object at 0x3e64ddf98>
# <keras.layers.merge.Add object at 0x3e67625f8>
# <keras.layers.convolutional.Cropping2D object at 0x3e68be470>
# <keras.layers.merge.Concatenate object at 0x3e5a53cf8>
# <keras.layers.pooling.AveragePooling2D object at 0x3e688d2b0>
# <keras.layers.pooling.AveragePooling2D object at 0x3e68becf8>
# <keras.layers.convolutional.Conv2D object at 0x3e68a4710>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.1624
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.067981025414045 0.12397318114637113 TPL
# <keras.layers.convolutional.Conv2D object at 0x3e68d2be0>
# (1, 1, 1008, 168)
# (1008, 168)
# % spikes outside bulk 0.00
# % sigma 2.1479
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.052977675863011 0.1543423963915745 PL
# <keras.layers.core.Activation object at 0x3e5a8feb8>
# <keras.layers.merge.Concatenate object at 0x3e68d2ba8>
# <keras.layers.convolutional.Conv2D object at 0x3e5a75470>
# (1, 1, 1344, 336)
# (1344, 336)
# % spikes outside bulk 0.00
# % sigma 2.5387
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.406670440428654 0.10604320635749023 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e68ea198>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e68ea240>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e6ad1400>
# <keras.layers.core.Activation object at 0x3e6c66eb8>
# <keras.layers.core.Activation object at 0x3e6f17cf8>
# <keras.layers.core.Activation object at 0x3e7195208>
# <keras.layers.core.Activation object at 0x3e756d588>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6af1ac8>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6c92940>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6f17a58>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e71abc50>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e756d048>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e6b276d8>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e6d89b38>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e703bac8>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e729ce48>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e756dcf8>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e6b27a90>
# <keras.layers.core.Activation object at 0x3e6dc0320>
# <keras.layers.core.Activation object at 0x3e7054390>
# <keras.layers.core.Activation object at 0x3e72d5630>
# <keras.layers.core.Activation object at 0x3e757e048>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6b3fe80>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e6dd6d68>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e70706d8>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e72ed940>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7595a58>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e6c50710>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e6ec7f60>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e715da20>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e73d9ef0>
# (336,)
# (1, 336)
# <keras.layers.pooling.AveragePooling2D object at 0x3e7414a58>
# <keras.layers.pooling.AveragePooling2D object at 0x3e74f43c8>
# <keras.layers.pooling.AveragePooling2D object at 0x3e7515f60>
# <keras.layers.normalization.BatchNormalization object at 0x3e7687c50>
# (336,)
# (1, 336)
# <keras.layers.merge.Add object at 0x3e6a38e80>
# <keras.layers.merge.Add object at 0x3e6efe748>
# <keras.layers.merge.Add object at 0x3e742de48>
# <keras.layers.merge.Add object at 0x3e7555e80>
# <keras.layers.merge.Add object at 0x3e756d4e0>
# <keras.layers.merge.Concatenate object at 0x3e69f32e8>
# <keras.layers.core.Activation object at 0x3e7704da0>
# <keras.layers.core.Activation object at 0x3e76bd438>
# <keras.layers.convolutional.Conv2D object at 0x3e7704fd0>
# (1, 1, 1344, 336)
# (1344, 336)
# % spikes outside bulk 0.00
# % sigma 2.8976
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.542721120355878 0.09214811313371785 PL
# <keras.layers.convolutional.Conv2D object at 0x3e76d4e80>
# (1, 1, 2016, 336)
# (2016, 336)
# % spikes outside bulk 0.00
# % sigma 3.1406
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.868041831343238 0.09775010733356515 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e77c19e8>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e7817208>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e79bec88>
# <keras.layers.core.Activation object at 0x3e7b93240>
# <keras.layers.core.Activation object at 0x3e7e2de80>
# <keras.layers.core.Activation object at 0x3e80ab550>
# <keras.layers.core.Activation object at 0x3e84848d0>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7a04e10>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7ba9c88>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7e7a4e0>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e80c5f98>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8484828>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e7a42a20>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e7c9ee80>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e7f54e10>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e81b0e10>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8484fd0>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e7a543c8>
# <keras.layers.core.Activation object at 0x3e7cd6668>
# <keras.layers.core.Activation object at 0x3e7f6d128>
# <keras.layers.core.Activation object at 0x3e81eb978>
# <keras.layers.core.Activation object at 0x3e8497358>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7a6e710>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7cec978>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e7f84b70>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8202d68>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e84a9da0>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e7b5ca58>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e7dd9f28>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8073d68>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e82edf60>
# (336,)
# (1, 336)
# <keras.layers.pooling.AveragePooling2D object at 0x3e8343390>
# <keras.layers.pooling.AveragePooling2D object at 0x3e83a7ef0>
# <keras.layers.pooling.AveragePooling2D object at 0x3e844ea20>
# <keras.layers.normalization.BatchNormalization object at 0x3e8597f98>
# (336,)
# (1, 336)
# <keras.layers.merge.Add object at 0x3e7953dd8>
# <keras.layers.merge.Add object at 0x3e7e13a90>
# <keras.layers.merge.Add object at 0x3e835f6d8>
# <keras.layers.merge.Add object at 0x3e8484208>
# <keras.layers.merge.Add object at 0x3e8484668>
# <keras.layers.merge.Concatenate object at 0x3e78dfeb8>
# <keras.layers.core.Activation object at 0x3e86351d0>
# <keras.layers.core.Activation object at 0x3e7921ef0>
# <keras.layers.convolutional.Conv2D object at 0x3e8635358>
# (1, 1, 2016, 336)
# (2016, 336)
# % spikes outside bulk 0.00
# % sigma 3.4706
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.9146237942100344 0.10566207059253774 TPL
# <keras.layers.convolutional.Conv2D object at 0x3e79092b0>
# (1, 1, 2016, 336)
# (2016, 336)
# % spikes outside bulk 0.00
# % sigma 3.1419
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.068043445733608 0.06397530932218065 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e86d3d30>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e872c550>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e88f9518>
# <keras.layers.core.Activation object at 0x3e8aaa588>
# <keras.layers.core.Activation object at 0x3e8d5d710>
# <keras.layers.core.Activation object at 0x3e8fbe898>
# <keras.layers.core.Activation object at 0x3e9397c18>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e893f198>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8ac4fd0>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8d8e828>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9006e10>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9397b70>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e8957d68>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8bb2e48>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8e80198>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e90c2f60>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e93ac3c8>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e896f160>
# <keras.layers.core.Activation object at 0x3e8beb9b0>
# <keras.layers.core.Activation object at 0x3e8e80470>
# <keras.layers.core.Activation object at 0x3e90ffcc0>
# <keras.layers.core.Activation object at 0x3e93ac6a0>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8986ba8>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8c03da0>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e8e96eb8>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9117eb8>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e93f0c18>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e8a77da0>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8d12630>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e8f85d30>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e9225940>
# (336,)
# (1, 336)
# <keras.layers.pooling.AveragePooling2D object at 0x3e925a128>
# <keras.layers.pooling.AveragePooling2D object at 0x3e933bdd8>
# <keras.layers.pooling.AveragePooling2D object at 0x3e9363d68>
# <keras.layers.normalization.BatchNormalization object at 0x3e94acf60>
# (336,)
# (1, 336)
# <keras.layers.merge.Add object at 0x3e88815f8>
# <keras.layers.merge.Add object at 0x3e8d423c8>
# <keras.layers.merge.Add object at 0x3e9270b70>
# <keras.layers.merge.Add object at 0x3e9397550>
# <keras.layers.merge.Add object at 0x3e93979b0>
# <keras.layers.merge.Concatenate object at 0x3e88195f8>
# <keras.layers.core.Activation object at 0x3e954c470>
# <keras.layers.core.Activation object at 0x3e93974e0>
# <keras.layers.convolutional.Conv2D object at 0x3e954c6a0>
# (1, 1, 2016, 336)
# (2016, 336)
# % spikes outside bulk 0.00
# % sigma 3.4234
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.818407144468578 0.09533055773083954 PL
# <keras.layers.convolutional.Conv2D object at 0x3e94ffeb8>
# (1, 1, 2016, 336)
# (2016, 336)
# % spikes outside bulk 0.00
# % sigma 3.5914
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.3745209056869445 0.06463946201953646 PL
# <keras.layers.normalization.BatchNormalization object at 0x3e9626f98>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e96408d0>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e97cdfd0>
# <keras.layers.core.Activation object at 0x3e99bd908>
# <keras.layers.core.Activation object at 0x3e9c72be0>
# <keras.layers.core.Activation object at 0x3e9ed9c18>
# <keras.layers.core.Activation object at 0x3ea2adf28>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e984d518>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9a05dd8>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9ca3ba8>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9ef3e10>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ea2adef0>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e9880128>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e9ac3ef0>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3e9d9a518>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3ea000898>
# (336,)
# (1, 336)
# <keras.layers.normalization.BatchNormalization object at 0x3ea2c5748>
# (336,)
# (1, 336)
# <keras.layers.core.Activation object at 0x3e98804e0>
# <keras.layers.core.Activation object at 0x3e9affd30>
# <keras.layers.core.Activation object at 0x3e9d9a7f0>
# <keras.layers.core.Activation object at 0x3ea033080>
# <keras.layers.core.Activation object at 0x3ea2c5a20>
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9895f28>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9b19320>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3e9de2d68>
# (5, 5, 336, 1)
# (336, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ea047ac8>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ea2dae10>
# (3, 3, 336, 1)
# (336, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3e9985da0>
# (336,)
# (1, 336)
# ...
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.494143899419578 0.03324984348437443 PL
# <keras.layers.convolutional.Conv2D object at 0x3eeead438>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 5.0322
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.378788226147598 0.06770536429047469 PL
# <keras.layers.normalization.BatchNormalization object at 0x3ef140dd8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3ef1597f0>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3ef303198>
# <keras.layers.core.Activation object at 0x3ef4d7828>
# <keras.layers.core.Activation object at 0x3ef788b00>
# <keras.layers.core.Activation object at 0x3ef9f2b38>
# <keras.layers.core.Activation object at 0x3efdcce48>
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef367438>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef51fda0>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef7baac8>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3efa08f28>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3efdcce10>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3ef385f28>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3ef5dbef0>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3ef8b4438>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3efb1c7b8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3efde2668>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3ef3a0400>
# <keras.layers.core.Activation object at 0x3ef619c50>
# <keras.layers.core.Activation object at 0x3ef8b4710>
# <keras.layers.core.Activation object at 0x3efb35f60>
# <keras.layers.core.Activation object at 0x3efde2940>
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef3b2e48>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef632e48>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3ef8f9c88>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3efbadfd0>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3efe22e10>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3ef4a1cc0>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3ef7408d0>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3ef9b6f98>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3efc57be0>
# (672,)
# (1, 672)
# <keras.layers.pooling.AveragePooling2D object at 0x3efc8a3c8>
# <keras.layers.pooling.AveragePooling2D object at 0x3efd6dda0>
# <keras.layers.pooling.AveragePooling2D object at 0x3efd92c88>
# <keras.layers.normalization.BatchNormalization object at 0x3efedaf28>
# (672,)
# (1, 672)
# <keras.layers.merge.Add object at 0x3ef2ae898>
# <keras.layers.merge.Add object at 0x3ef7710b8>
# <keras.layers.merge.Add object at 0x3efca5e10>
# <keras.layers.merge.Add object at 0x3efdcc7f0>
# <keras.layers.merge.Add object at 0x3efdccc50>
# <keras.layers.merge.Concatenate object at 0x3ef248898>
# <keras.layers.core.Activation object at 0x3eff7d710>
# <keras.layers.core.Activation object at 0x3eff1cd68>
# <keras.layers.convolutional.Conv2D object at 0x3eff7d940>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 5.2486
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.275131758445399 0.0849556697024334 PL
# <keras.layers.convolutional.Conv2D object at 0x3eff4e358>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 6.3586
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.7404526179414175 0.0856340036219777 PL
# <keras.layers.normalization.BatchNormalization object at 0x3f003d358>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0075b38>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f025fe80>
# <keras.layers.core.Activation object at 0x3f03f3b70>
# <keras.layers.core.Activation object at 0x3f06a4e48>
# <keras.layers.core.Activation object at 0x3f090ce80>
# <keras.layers.core.Activation object at 0x3f0cc5240>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0282780>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f040cf60>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f06d3e10>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0938908>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0cc5128>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f02b9390>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f051d7f0>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f07ca780>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0a2fb00>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0cc59b0>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f02b9748>
# <keras.layers.core.Activation object at 0x3f054b550>
# <keras.layers.core.Activation object at 0x3f07caa58>
# <keras.layers.core.Activation object at 0x3f0a6a2e8>
# <keras.layers.core.Activation object at 0x3f0cc5c88>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f02fccc0>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0562a20>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f07e4e48>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0b1ac18>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f0cd7e80>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f03b8e10>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0656c18>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f08f46d8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0b5bf28>
# (672,)
# (1, 672)
# <keras.layers.pooling.AveragePooling2D object at 0x3f0b85710>
# <keras.layers.pooling.AveragePooling2D object at 0x3f0c2ab38>
# <keras.layers.pooling.AveragePooling2D object at 0x3f0c70f98>
# <keras.layers.normalization.BatchNormalization object at 0x3f0dde908>
# (672,)
# (1, 672)
# <keras.layers.merge.Add object at 0x3f01cdbe0>
# <keras.layers.merge.Add object at 0x3f068d400>
# <keras.layers.merge.Add object at 0x3f0be1160>
# <keras.layers.merge.Add object at 0x3f0caeb38>
# <keras.layers.merge.Add object at 0x3f0caefd0>
# <keras.layers.merge.Concatenate object at 0x3f0163be0>
# <keras.layers.core.Activation object at 0x3f0e5ca58>
# <keras.layers.core.Activation object at 0x3f0e160f0>
# <keras.layers.convolutional.Conv2D object at 0x3f0e5cc88>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 4.6681
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.804931970773591 0.08274559286767702 PL
# <keras.layers.convolutional.Conv2D object at 0x3f0e2cb38>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 5.8350
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.171198222558351 0.08870392693675289 PL
# <keras.layers.normalization.BatchNormalization object at 0x3f0f186a0>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f0f51e80>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f113b400>
# <keras.layers.core.Activation object at 0x3f12d2eb8>
# <keras.layers.core.Activation object at 0x3f1585cf8>
# <keras.layers.core.Activation object at 0x3f1805208>
# <keras.layers.core.Activation object at 0x3f1bd9588>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f115aac8>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f12ff940>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1585a58>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1817c50>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1bd9048>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f11926d8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f13f8b38>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f16acac8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f190ae48>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f1bd9cf8>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f1192a90>
# <keras.layers.core.Activation object at 0x3f142e320>
# <keras.layers.core.Activation object at 0x3f16c3390>
# <keras.layers.core.Activation object at 0x3f193f630>
# <keras.layers.core.Activation object at 0x3f1bea048>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f11abe80>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1445d68>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f16de6d8>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1959940>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f1c01a58>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f12bd710>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f1535f60>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f17cca20>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f1a43ef0>
# (672,)
# (1, 672)
# <keras.layers.pooling.AveragePooling2D object at 0x3f1a81a58>
# <keras.layers.pooling.AveragePooling2D object at 0x3f1b5f3c8>
# <keras.layers.pooling.AveragePooling2D object at 0x3f1b80f60>
# <keras.layers.normalization.BatchNormalization object at 0x3f1cf3c50>
# (672,)
# (1, 672)
# <keras.layers.merge.Add object at 0x3f10a5e80>
# <keras.layers.merge.Add object at 0x3f1568748>
# <keras.layers.merge.Add object at 0x3f1a99e48>
# <keras.layers.merge.Add object at 0x3f1bc3e80>
# <keras.layers.merge.Add object at 0x3f1bd94e0>
# <keras.layers.merge.Concatenate object at 0x3f105d2e8>
# <keras.layers.core.Activation object at 0x3f1d6eda0>
# <keras.layers.core.Activation object at 0x3f1d29438>
# <keras.layers.convolutional.Conv2D object at 0x3f1d6efd0>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 4.8625
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.991515651659763 0.10294564804561657 PL
# <keras.layers.convolutional.Conv2D object at 0x3f1d41e80>
# (1, 1, 4032, 672)
# (4032, 672)
# % spikes outside bulk 0.00
# % sigma 5.1588
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# 4.865356453506756 0.08546132342475532 PL
# <keras.layers.normalization.BatchNormalization object at 0x3f1e2f9e8>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f1e85208>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f202dc88>
# <keras.layers.core.Activation object at 0x3f2202240>
# <keras.layers.core.Activation object at 0x3f249ae80>
# <keras.layers.core.Activation object at 0x3f271b550>
# <keras.layers.core.Activation object at 0x3f2af28d0>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2073e10>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2219c88>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f24e54e0>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2732f98>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2af2828>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f20b0a20>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f230be80>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f25c1e10>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f281de10>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f2af2fd0>
# (672,)
# (1, 672)
# <keras.layers.core.Activation object at 0x3f20c43c8>
# <keras.layers.core.Activation object at 0x3f2343668>
# <keras.layers.core.Activation object at 0x3f25dd128>
# <keras.layers.core.Activation object at 0x3f285b978>
# <keras.layers.core.Activation object at 0x3f2b05358>
# <keras.layers.convolutional.SeparableConv2D object at 0x3f20e0710>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f235b978>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f25f4b70>
# (5, 5, 672, 1)
# (672, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2875d68>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x3f2b1ada0>
# (3, 3, 672, 1)
# (672, 9)
# <keras.layers.normalization.BatchNormalization object at 0x3f21cea58>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f2445f28>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f26e3d68>
# (672,)
# (1, 672)
# <keras.layers.normalization.BatchNormalization object at 0x3f2959f60>
# (672,)
# (1, 672)
# <keras.layers.pooling.AveragePooling2D object at 0x3f29b4390>
# <keras.layers.pooling.AveragePooling2D object at 0x3f2a17ef0>
# <keras.layers.pooling.AveragePooling2D object at 0x3f2abda20>
# <keras.layers.normalization.BatchNormalization object at 0x3f2c08f98>
# (672,)
# (1, 672)
# <keras.layers.merge.Add object at 0x3f1fbfdd8>
# <keras.layers.merge.Add object at 0x3f2482a90>
# <keras.layers.merge.Add object at 0x3f29d06d8>
# <keras.layers.merge.Add object at 0x3f2af2208>
# <keras.layers.merge.Add object at 0x3f2af2668>
# <keras.layers.merge.Concatenate object at 0x3f1f52eb8>
# <keras.layers.core.Activation object at 0x3017fc320>
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x3016dd8d0>
# <keras.layers.core.Dense object at 0x3f2c41780>
# (4032, 1000)
# (4032, 1000)
# % spikes outside bulk 0.00
# % sigma 4.5432
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# Calculating best minimal value for power law fit
# 3.4568706115026635 0.02751621924727904 PL
# Assuming nested distributions

# %%
print(len(alphas))
plt.hist(alphas,bins=30);
plt.title("power law fits, NasNetLarge")
# Out:
# 45
# Text(0.5,1,'power law fits, NasNetLarge')

# %%
for kmodel in [nasnet.NASNetMobile]:
    kmodel(weights=None)
    model = kmodel(weights='imagenet')
    alphas = analyze_model(model)
# Out:
# <keras.engine.topology.InputLayer object at 0x45f9732e8>
# <keras.layers.convolutional.Conv2D object at 0x45f973390>
# (3, 3, 3, 32)
# (27, 32)
# <keras.layers.normalization.BatchNormalization object at 0x45f973978>
# (32,)
# (1, 32)
# <keras.layers.core.Activation object at 0x45f9d63c8>
# <keras.layers.convolutional.Conv2D object at 0x45fa21da0>
# (1, 1, 32, 11)
# (32, 11)
# <keras.layers.normalization.BatchNormalization object at 0x45fa64fd0>
# (11,)
# (1, 11)
# <keras.layers.core.Activation object at 0x45fb5d3c8>
# <keras.layers.core.Activation object at 0x45fd13438>
# <keras.layers.convolutional.SeparableConv2D object at 0x45fb7df28>
# (5, 5, 11, 1)
# (11, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x45fd2be80>
# (7, 7, 32, 1)
# (32, 49)
# <keras.layers.normalization.BatchNormalization object at 0x45fbbdc18>
# (11,)
# (1, 11)
# <keras.layers.normalization.BatchNormalization object at 0x45fe17cf8>
# (11,)
# (1, 11)
# <keras.layers.core.Activation object at 0x45fbd2048>
# <keras.layers.core.Activation object at 0x45fe4e860>
# <keras.layers.convolutional.SeparableConv2D object at 0x45fbe7a58>
# (5, 5, 11, 1)
# (11, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x45fe9add8>
# (7, 7, 11, 1)
# (11, 49)
# <keras.layers.normalization.BatchNormalization object at 0x45fcdbc50>
# (11,)
# (1, 11)
# <keras.layers.normalization.BatchNormalization object at 0x45ff54f28>
# (11,)
# (1, 11)
# <keras.layers.core.Activation object at 0x4600705f8>
# <keras.layers.merge.Add object at 0x45fae54a8>
# <keras.layers.convolutional.SeparableConv2D object at 0x4600d5fd0>
# (7, 7, 32, 1)
# (32, 49)
# <keras.layers.core.Activation object at 0x460309438>
# <keras.layers.core.Activation object at 0x4619cbe10>
# <keras.layers.normalization.BatchNormalization object at 0x4600ed3c8>
# (11,)
# (1, 11)
# <keras.layers.convolutional.SeparableConv2D object at 0x460328f98>
# (5, 5, 32, 1)
# (32, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x461a07da0>
# (3, 3, 11, 1)
# (11, 9)
# <keras.layers.core.Activation object at 0x4600ed6a0>
# <keras.layers.normalization.BatchNormalization object at 0x460386208>
# (11,)
# (1, 11)
# <keras.layers.normalization.BatchNormalization object at 0x461a1f2b0>
# (11,)
# (1, 11)
# <keras.layers.convolutional.SeparableConv2D object at 0x460130c18>
# (7, 7, 11, 1)
# (11, 49)
# <keras.layers.core.Activation object at 0x4603864e0>
# <keras.layers.core.Activation object at 0x461a1f588>
# <keras.layers.pooling.MaxPooling2D object at 0x45ff96c88>
# <keras.layers.normalization.BatchNormalization object at 0x4601edf60>
# (11,)
# (1, 11)
# <keras.layers.convolutional.SeparableConv2D object at 0x46039bf28>
# (5, 5, 11, 1)
# (11, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x461a35fd0>
# (3, 3, 11, 1)
# (11, 9)
# <keras.layers.core.Activation object at 0x461b78da0>
# <keras.layers.merge.Add object at 0x45ffabe80>
# <keras.layers.pooling.AveragePooling2D object at 0x46022aac8>
# <keras.layers.normalization.BatchNormalization object at 0x46048ada0>
# (11,)
# (1, 11)
# <keras.layers.pooling.AveragePooling2D object at 0x4604c5908>
# <keras.layers.normalization.BatchNormalization object at 0x461b22e48>
# (11,)
# (1, 11)
# <keras.layers.pooling.MaxPooling2D object at 0x4604ddcf8>
# <keras.layers.convolutional.ZeroPadding2D object at 0x461cb8630>
# <keras.layers.merge.Add object at 0x460243eb8>
# <keras.layers.merge.Add object at 0x46192a358>
# <keras.layers.merge.Add object at 0x461b5c9b0>
# <keras.layers.convolutional.Cropping2D object at 0x461cb8828>
# <keras.layers.merge.Concatenate object at 0x45faa1d30>
# <keras.layers.pooling.AveragePooling2D object at 0x461ca2e80>
# <keras.layers.pooling.AveragePooling2D object at 0x461cb8ef0>
# <keras.layers.core.Activation object at 0x45fab81d0>
# <keras.layers.convolutional.Conv2D object at 0x461ca2e48>
# (1, 1, 32, 11)
# (32, 11)
# <keras.layers.convolutional.Conv2D object at 0x461cd0fd0>
# (1, 1, 32, 11)
# (32, 11)
# <keras.layers.convolutional.Conv2D object at 0x45fab8cf8>
# (1, 1, 44, 22)
# (44, 22)
# <keras.layers.merge.Concatenate object at 0x461cd0f98>
# <keras.layers.normalization.BatchNormalization object at 0x461cfad68>
# (22,)
# (1, 22)
# <keras.layers.normalization.BatchNormalization object at 0x461ce4438>
# (22,)
# (1, 22)
# <keras.layers.core.Activation object at 0x461ea2cf8>
# <keras.layers.core.Activation object at 0x46207e2b0>
# <keras.layers.convolutional.SeparableConv2D object at 0x461ee9e80>
# (5, 5, 22, 1)
# (22, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x462093cf8>
# (7, 7, 22, 1)
# (22, 49)
# <keras.layers.normalization.BatchNormalization object at 0x461f3c438>
# (22,)
# (1, 22)
# <keras.layers.normalization.BatchNormalization object at 0x462184ef0>
# (22,)
# (1, 22)
# <keras.layers.core.Activation object at 0x461f24e48>
# <keras.layers.core.Activation object at 0x4621bd6d8>
# <keras.layers.convolutional.SeparableConv2D object at 0x461f568d0>
# (5, 5, 22, 1)
# (22, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x462205c50>
# (7, 7, 22, 1)
# (22, 49)
# <keras.layers.normalization.BatchNormalization object at 0x462045ac8>
# (22,)
# (1, 22)
# <keras.layers.normalization.BatchNormalization object at 0x4622c2f98>
# (22,)
# (1, 22)
# <keras.layers.core.Activation object at 0x4623e0470>
# <keras.layers.merge.Add object at 0x461e38da0>
# <keras.layers.convolutional.SeparableConv2D object at 0x46242c0f0>
# (7, 7, 22, 1)
# (22, 49)
# <keras.layers.core.Activation object at 0x46264dd68>
# <keras.layers.core.Activation object at 0x462934c88>
# <keras.layers.normalization.BatchNormalization object at 0x46245b240>
# (22,)
# (1, 22)
# <keras.layers.convolutional.SeparableConv2D object at 0x462699ef0>
# (5, 5, 22, 1)
# (22, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x462970c18>
# (3, 3, 22, 1)
# (22, 9)
# <keras.layers.core.Activation object at 0x46245b518>
# <keras.layers.normalization.BatchNormalization object at 0x4626d9ef0>
# (22,)
# (1, 22)
# <keras.layers.normalization.BatchNormalization object at 0x46298c128>
# (22,)
# (1, 22)
# <keras.layers.convolutional.SeparableConv2D object at 0x46246df60>
# (7, 7, 22, 1)
# (22, 49)
# <keras.layers.core.Activation object at 0x4626f5358>
# <keras.layers.core.Activation object at 0x46298c400>
# <keras.layers.pooling.MaxPooling2D object at 0x4622fbb00>
# <keras.layers.normalization.BatchNormalization object at 0x46255ddd8>
# (22,)
# (1, 22)
# <keras.layers.convolutional.SeparableConv2D object at 0x462708da0>
# (5, 5, 22, 1)
# (22, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x4629a1e48>
# (3, 3, 22, 1)
# (22, 9)
# <keras.layers.core.Activation object at 0x462bf0470>
# <keras.layers.merge.Add object at 0x462319ef0>
# <keras.layers.pooling.AveragePooling2D object at 0x462597940>
# <keras.layers.normalization.BatchNormalization object at 0x4627f7f98>
# (22,)
# (1, 22)
# <keras.layers.pooling.AveragePooling2D object at 0x462832780>
# <keras.layers.normalization.BatchNormalization object at 0x462a8ecc0>
# (22,)
# (1, 22)
# <keras.layers.pooling.MaxPooling2D object at 0x46284da90>
# <keras.layers.convolutional.ZeroPadding2D object at 0x462c0afd0>
# <keras.layers.merge.Add object at 0x4625fa390>
# <keras.layers.merge.Add object at 0x4628981d0>
# <keras.layers.merge.Add object at 0x462ac6828>
# <keras.layers.convolutional.Cropping2D object at 0x462c216a0>
# <keras.layers.merge.Concatenate object at 0x461dc5fd0>
# <keras.layers.pooling.AveragePooling2D object at 0x462bf04e0>
# <keras.layers.pooling.AveragePooling2D object at 0x462c21dd8>
# <keras.layers.convolutional.Conv2D object at 0x462c0a940>
# (1, 1, 44, 22)
# (44, 22)
# <keras.layers.convolutional.Conv2D object at 0x462c36e10>
# (1, 1, 44, 22)
# (44, 22)
# <keras.layers.core.Activation object at 0x461e09ef0>
# <keras.layers.merge.Concatenate object at 0x462c36dd8>
# <keras.layers.convolutional.Conv2D object at 0x461def320>
# (1, 1, 88, 44)
# (88, 44)
# RMT_Util.ipynb:7: RuntimeWarning: divide by zero encountered in true_divide
#   "## RMT Util\n",
# RMT_Util.ipynb:7: RuntimeWarning: invalid value encountered in sqrt
#   "## RMT Util\n",
# % spikes outside bulk 0.00
# % sigma 1.8228
# Calculating best minimal value for power law fit
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Assuming nested distributions
# 2.815562533203923 0.23205198050899212 PL
# <keras.layers.normalization.BatchNormalization object at 0x462c4c2b0>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x462c62be0>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x462e0bb70>
# <keras.layers.core.Activation object at 0x462fe1128>
# <keras.layers.core.Activation object at 0x463279d68>
# <keras.layers.core.Activation object at 0x4634f5438>
# <keras.layers.core.Activation object at 0x4638ca7b8>
# <keras.layers.convolutional.SeparableConv2D object at 0x462e51cf8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x462ff5b70>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4632c63c8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46350be80>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4638ca710>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x462e8b908>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4630e9d68>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4633a4cf8>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4635f9cf8>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4638caf28>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x462e8bcc0>
# <keras.layers.core.Activation object at 0x46311e550>
# <keras.layers.core.Activation object at 0x4633b9048>
# <keras.layers.core.Activation object at 0x463631860>
# <keras.layers.core.Activation object at 0x4638dd240>
# <keras.layers.convolutional.SeparableConv2D object at 0x462ea1eb8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x463137f98>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4633cea58>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x463679dd8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4638f1c88>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x462fae940>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x463226e10>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4634bcc50>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x463733f28>
# (44,)
# (1, 44)
# <keras.layers.pooling.AveragePooling2D object at 0x463776c88>
# <keras.layers.pooling.AveragePooling2D object at 0x46384e5f8>
# <keras.layers.pooling.AveragePooling2D object at 0x4638951d0>
# <keras.layers.normalization.BatchNormalization object at 0x4639e1e80>
# (44,)
# (1, 44)
# <keras.layers.merge.Add object at 0x462d9acc0>
# <keras.layers.merge.Add object at 0x46325f978>
# <keras.layers.merge.Add object at 0x46378de80>
# <keras.layers.merge.Add object at 0x4638ca128>
# <keras.layers.merge.Add object at 0x4638ca550>
# <keras.layers.merge.Concatenate object at 0x462d33da0>
# <keras.layers.core.Activation object at 0x463a5cf98>
# <keras.layers.core.Activation object at 0x462d6ef60>
# <keras.layers.convolutional.Conv2D object at 0x463a5cbe0>
# (1, 1, 88, 44)
# (88, 44)
# % spikes outside bulk 0.00
# % sigma 1.9235
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.6549316703669752 0.24478123008295616 TPL
# <keras.layers.convolutional.Conv2D object at 0x462d55518>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 2.2511
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 6.902018291076098 0.16666666666666696 PL
# <keras.layers.normalization.BatchNormalization object at 0x463b18c18>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x463b70358>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x463d3a400>
# <keras.layers.core.Activation object at 0x463eef470>
# <keras.layers.core.Activation object at 0x464183eb8>
# <keras.layers.core.Activation object at 0x464403780>
# <keras.layers.core.Activation object at 0x4647d6b00>
# <keras.layers.convolutional.SeparableConv2D object at 0x463d5bf60>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x463f06eb8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4641ce710>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x464449cf8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4647d6a58>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x463d99c50>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x463ff0d30>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4642a9fd0>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x464504e48>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4647ec2b0>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x463daf048>
# <keras.layers.core.Activation object at 0x464028898>
# <keras.layers.core.Activation object at 0x4642c9358>
# <keras.layers.core.Activation object at 0x464542ba8>
# <keras.layers.core.Activation object at 0x4647ec588>
# <keras.layers.convolutional.SeparableConv2D object at 0x463dc3a90>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x464070e10>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4642dcda0>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x464557eb8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x464801fd0>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x463eb7c88>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x464130f60>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4643c9f98>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x464669828>
# (44,)
# (1, 44)
# <keras.layers.pooling.AveragePooling2D object at 0x464699048>
# <keras.layers.pooling.AveragePooling2D object at 0x464756940>
# <keras.layers.pooling.AveragePooling2D object at 0x4647a1c50>
# <keras.layers.normalization.BatchNormalization object at 0x4648e9e48>
# (44,)
# (1, 44)
# <keras.layers.merge.Add object at 0x463cc64e0>
# <keras.layers.merge.Add object at 0x46416ecc0>
# <keras.layers.merge.Add object at 0x4646ada58>
# <keras.layers.merge.Add object at 0x4647d6438>
# <keras.layers.merge.Add object at 0x4647d6898>
# <keras.layers.merge.Concatenate object at 0x463c664e0>
# <keras.layers.core.Activation object at 0x464988400>
# <keras.layers.core.Activation object at 0x4649269b0>
# <keras.layers.convolutional.Conv2D object at 0x464a26f60>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 2.5587
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6403800482216324 0.23602718226131467 EXP
# <keras.layers.convolutional.Conv2D object at 0x4647d63c8>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 2.6228
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.9675838731323927 0.197196482959979 TPL
# <keras.layers.normalization.BatchNormalization object at 0x464a65d68>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x464a7d780>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x464c24278>
# <keras.layers.core.Activation object at 0x464dfa7b8>
# <keras.layers.core.Activation object at 0x4650a4a90>
# <keras.layers.core.Activation object at 0x46530aac8>
# <keras.layers.core.Activation object at 0x4656e4dd8>
# <keras.layers.convolutional.SeparableConv2D object at 0x464c8a3c8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x464e43d30>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4650d8a58>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x465323eb8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4656e4da0>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x464ca7f98>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x464f00e80>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4651d03c8>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x465436748>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4656f85f8>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x464cbe390>
# <keras.layers.core.Activation object at 0x464f3cbe0>
# <keras.layers.core.Activation object at 0x4651d06a0>
# <keras.layers.core.Activation object at 0x46544bef0>
# <keras.layers.core.Activation object at 0x4656f88d0>
# <keras.layers.convolutional.SeparableConv2D object at 0x464cd5dd8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x464f53e48>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x465217c18>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46547c978>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x465737da0>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x464dc3fd0>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x465060860>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4652d0f60>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x46556cb70>
# (44,)
# (1, 44)
# <keras.layers.pooling.AveragePooling2D object at 0x4655a7358>
# <keras.layers.pooling.AveragePooling2D object at 0x46565ec88>
# <keras.layers.pooling.AveragePooling2D object at 0x4656a9f98>
# <keras.layers.normalization.BatchNormalization object at 0x4657f5fd0>
# (44,)
# (1, 44)
# <keras.layers.merge.Add object at 0x464bd0828>
# <keras.layers.merge.Add object at 0x465090048>
# <keras.layers.merge.Add object at 0x4655bdda0>
# <keras.layers.merge.Add object at 0x4656e4780>
# <keras.layers.merge.Add object at 0x4656e4be0>
# <keras.layers.merge.Concatenate object at 0x464b6a828>
# <keras.layers.core.Activation object at 0x465894748>
# <keras.layers.core.Activation object at 0x465832cf8>
# <keras.layers.convolutional.Conv2D object at 0x4658946a0>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 2.6483
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.9700989986343087 0.1741652535800493 PL
# <keras.layers.convolutional.Conv2D object at 0x4656e4710>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 2.3281
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.5659579049057535 0.17431129540657164 PL
# <keras.layers.normalization.BatchNormalization object at 0x4659542e8>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x46598cac8>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x465b71e10>
# <keras.layers.core.Activation object at 0x465d09b00>
# <keras.layers.core.Activation object at 0x465fb9dd8>
# <keras.layers.core.Activation object at 0x46621de10>
# <keras.layers.core.Activation object at 0x4666091d0>
# <keras.layers.convolutional.SeparableConv2D object at 0x465b98710>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x465d1fef0>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x465fe9da0>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46624a898>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4666090b8>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x465bcd320>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x465e31780>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x4660e0710>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x466340a90>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x466609940>
# (44,)
# (1, 44)
# <keras.layers.core.Activation object at 0x465bcd6d8>
# <keras.layers.core.Activation object at 0x465e48f28>
# <keras.layers.core.Activation object at 0x4660e09e8>
# <keras.layers.core.Activation object at 0x466377278>
# <keras.layers.core.Activation object at 0x466609c18>
# <keras.layers.convolutional.SeparableConv2D object at 0x465c0fc50>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x465ec4f98>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4660fadd8>
# (5, 5, 44, 1)
# (44, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46638bcc0>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46661ce10>
# (3, 3, 44, 1)
# (44, 9)
# <keras.layers.normalization.BatchNormalization object at 0x465cccf98>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x465f6bba8>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x466208668>
# (44,)
# (1, 44)
# <keras.layers.normalization.BatchNormalization object at 0x46647ceb8>
# (44,)
# (1, 44)
# <keras.layers.pooling.AveragePooling2D object at 0x4664b66a0>
# <keras.layers.pooling.AveragePooling2D object at 0x46656cfd0>
# <keras.layers.pooling.AveragePooling2D object at 0x4665b8f60>
# <keras.layers.normalization.BatchNormalization object at 0x466728898>
# (44,)
# (1, 44)
# <keras.layers.merge.Add object at 0x465adfb70>
# <keras.layers.merge.Add object at 0x465fa2390>
# <keras.layers.merge.Add object at 0x46651a0f0>
# <keras.layers.merge.Add object at 0x4665f1ac8>
# <keras.layers.merge.Add object at 0x4665f1fd0>
# <keras.layers.merge.Concatenate object at 0x465a74b70>
# <keras.layers.core.Activation object at 0x466759080>
# <keras.layers.core.Activation object at 0x4667a19e8>
# <keras.layers.convolutional.Conv2D object at 0x466770ac8>
# (1, 1, 264, 88)
# (264, 88)
# % spikes outside bulk 0.00
# % sigma 2.6355
# Calculating best minimal value for power law fit
# Assuming nested distributions
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/powerlaw.py:1602: RuntimeWarning: invalid value encountered in true_divide
#   CDF = CDF/norm
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# /Users/charlesmartin14/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# 4.651126941004838 0.11111111111111094 PL
# <keras.layers.convolutional.Conv2D object at 0x4667a1c18>
# (1, 1, 264, 88)
# (264, 88)
# % spikes outside bulk 0.00
# % sigma 2.2256
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.651423159881397 0.15659542292700918 PL
# <keras.layers.normalization.BatchNormalization object at 0x466895e10>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x466861630>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x466a83e80>
# <keras.layers.core.Activation object at 0x466c1ce48>
# <keras.layers.convolutional.SeparableConv2D object at 0x466aa4a58>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x466c4c8d0>
# (7, 7, 88, 1)
# (88, 49)
# % spikes outside bulk 0.00
# % sigma 0.1936
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.950228988561945 0.20348623049809855 PL
# <keras.layers.normalization.BatchNormalization object at 0x466adc668>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x466d40ac8>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x466adca20>
# <keras.layers.core.Activation object at 0x466d7c2b0>
# <keras.layers.convolutional.SeparableConv2D object at 0x466af3e10>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x466d8fcf8>
# (7, 7, 88, 1)
# (88, 49)
# % spikes outside bulk 0.00
# % sigma 0.1905
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.520108408413318 0.22994338418645754 EXP
# <keras.layers.normalization.BatchNormalization object at 0x466c036a0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x466e7eef0>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x466f72b00>
# <keras.layers.merge.Add object at 0x4669ece10>
# <keras.layers.convolutional.SeparableConv2D object at 0x466fbcc88>
# (7, 7, 88, 1)
# (88, 49)
# % spikes outside bulk 0.00
# % sigma 1.0012
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.9188379020116524 0.2108971384881314 TPL
# <keras.layers.core.Activation object at 0x467237400>
# <keras.layers.core.Activation object at 0x4674f6860>
# <keras.layers.normalization.BatchNormalization object at 0x466ff8dd8>
# (88,)
# (1, 88)
# <keras.layers.convolutional.SeparableConv2D object at 0x467256ac8>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46752c7f0>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.core.Activation object at 0x46700e0f0>
# <keras.layers.normalization.BatchNormalization object at 0x4672a64e0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46752ccc0>
# (88,)
# (1, 88)
# <keras.layers.convolutional.SeparableConv2D object at 0x467026b38>
# (7, 7, 88, 1)
# (88, 49)
# % spikes outside bulk 0.00
# % sigma 2.0376
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 1.6025116485899553 0.11838868378407719 PL
# <keras.layers.core.Activation object at 0x467293ef0>
# <keras.layers.core.Activation object at 0x467544550>
# <keras.layers.pooling.MaxPooling2D object at 0x466eb66d8>
# <keras.layers.normalization.BatchNormalization object at 0x467119d30>
# (88,)
# (1, 88)
# <keras.layers.convolutional.SeparableConv2D object at 0x4672be978>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46755ba20>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.core.Activation object at 0x4677ac048>
# <keras.layers.merge.Add object at 0x466f1e128>
# <keras.layers.pooling.AveragePooling2D object at 0x46714f518>
# <keras.layers.normalization.BatchNormalization object at 0x4673b5b70>
# (88,)
# (1, 88)
# <keras.layers.pooling.AveragePooling2D object at 0x4673ee358>
# <keras.layers.normalization.BatchNormalization object at 0x46764dc18>
# (88,)
# (1, 88)
# <keras.layers.pooling.MaxPooling2D object at 0x467433d68>
# <keras.layers.convolutional.ZeroPadding2D object at 0x4677c3ef0>
# <keras.layers.merge.Add object at 0x467168f60>
# <keras.layers.merge.Add object at 0x467403da0>
# <keras.layers.merge.Add object at 0x467683400>
# <keras.layers.convolutional.Cropping2D object at 0x4677df080>
# <keras.layers.merge.Concatenate object at 0x4669a2278>
# <keras.layers.pooling.AveragePooling2D object at 0x4677ac0b8>
# <keras.layers.pooling.AveragePooling2D object at 0x4677df320>
# <keras.layers.convolutional.Conv2D object at 0x4677c3518>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 1.5612
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.8178282448385765 0.2321084613423962 PL
# <keras.layers.convolutional.Conv2D object at 0x4677f69e8>
# (1, 1, 264, 44)
# (264, 44)
# % spikes outside bulk 0.00
# % sigma 1.7105
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.6315904788425435 0.2243047882289666 PL
# <keras.layers.core.Activation object at 0x4669beeb8>
# <keras.layers.merge.Concatenate object at 0x4677f6eb8>
# <keras.layers.convolutional.Conv2D object at 0x4669becc0>
# (1, 1, 352, 88)
# (352, 88)
# % spikes outside bulk 0.00
# % sigma 2.1806
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.168064346537209 0.14839559615108577 PL
# <keras.layers.normalization.BatchNormalization object at 0x46780b2b0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46780b128>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x4679ccc50>
# <keras.layers.core.Activation object at 0x467b83cc0>
# <keras.layers.core.Activation object at 0x467e35f98>
# <keras.layers.core.Activation object at 0x4680b1048>
# <keras.layers.core.Activation object at 0x468485390>
# <keras.layers.convolutional.SeparableConv2D object at 0x467a128d0>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x467b9eeb8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x467e62eb8>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x4680c5a58>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4684852e8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x467a494e0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x467ca8940>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x467f588d0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x4681b9c50>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468485b00>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x467a49898>
# <keras.layers.core.Activation object at 0x467cde128>
# <keras.layers.core.Activation object at 0x467f58ba8>
# <keras.layers.core.Activation object at 0x4681ee438>
# <keras.layers.core.Activation object at 0x4684953c8>
# <keras.layers.convolutional.SeparableConv2D object at 0x467a8ee10>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x467cf6b70>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x467f75eb8>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x468206e80>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4684b0710>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x467b46f60>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x467de5d68>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468080828>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x4682f7cf8>
# (88,)
# (1, 88)
# <keras.layers.pooling.AveragePooling2D object at 0x46832e860>
# <keras.layers.pooling.AveragePooling2D object at 0x4683e4c88>
# <keras.layers.pooling.AveragePooling2D object at 0x46842ef28>
# <keras.layers.normalization.BatchNormalization object at 0x46859fa58>
# (88,)
# (1, 88)
# <keras.layers.merge.Add object at 0x46795ed30>
# <keras.layers.merge.Add object at 0x467e1d550>
# <keras.layers.merge.Add object at 0x4683922b0>
# <keras.layers.merge.Add object at 0x46846cc88>
# <keras.layers.merge.Add object at 0x468485240>
# <keras.layers.merge.Concatenate object at 0x4679160f0>
# <keras.layers.core.Activation object at 0x46861cba8>
# <keras.layers.core.Activation object at 0x4685d7240>
# <keras.layers.convolutional.Conv2D object at 0x46861cdd8>
# (1, 1, 352, 88)
# (352, 88)
# % spikes outside bulk 0.00
# % sigma 1.9895
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.086834415519036 0.15983095885089452 PL
# <keras.layers.convolutional.Conv2D object at 0x4685ebc88>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 3.1552
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.9184481807017146 0.08960775233585416 PL
# <keras.layers.normalization.BatchNormalization object at 0x4686db7f0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468716b00>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x4688dcf98>
# <keras.layers.core.Activation object at 0x468aae048>
# <keras.layers.core.Activation object at 0x468d3dfd0>
# <keras.layers.core.Activation object at 0x468fbf358>
# <keras.layers.core.Activation object at 0x4693976d8>
# <keras.layers.convolutional.SeparableConv2D object at 0x46891fc18>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x468ac6a90>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x468d3dcc0>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x468fd5da0>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x469397630>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x468957828>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468bb5c88>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468e7e4e0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x4690c1f98>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469397e48>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x468957be0>
# <keras.layers.core.Activation object at 0x468bed470>
# <keras.layers.core.Activation object at 0x468e68ef0>
# <keras.layers.core.Activation object at 0x4690fd780>
# <keras.layers.core.Activation object at 0x4693a7160>
# <keras.layers.convolutional.SeparableConv2D object at 0x468970e48>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x468c03eb8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x468e95978>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x469144cf8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x4693beba8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x468a7d860>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468cefd30>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x468f8ab70>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469201e48>
# (88,)
# (1, 88)
# <keras.layers.pooling.AveragePooling2D object at 0x469242ba8>
# <keras.layers.pooling.AveragePooling2D object at 0x46931b518>
# <keras.layers.pooling.AveragePooling2D object at 0x469367828>
# <keras.layers.normalization.BatchNormalization object at 0x4694afda0>
# (88,)
# (1, 88)
# <keras.layers.merge.Add object at 0x46886d908>
# <keras.layers.merge.Add object at 0x468d26898>
# <keras.layers.merge.Add object at 0x469258eb8>
# <keras.layers.merge.Add object at 0x469380e80>
# <keras.layers.merge.Add object at 0x469397470>
# <keras.layers.merge.Concatenate object at 0x4687ffcc0>
# <keras.layers.core.Activation object at 0x46952ab00>
# <keras.layers.core.Activation object at 0x46883de80>
# <keras.layers.convolutional.Conv2D object at 0x46952af98>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 2.6888
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.6364882217353127 0.14939736470519283 TPL
# <keras.layers.convolutional.Conv2D object at 0x468822438>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 2.7349
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.117488615789771 0.10916109583075248 PL
# <keras.layers.normalization.BatchNormalization object at 0x4695e8b38>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46963e278>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x469806320>
# <keras.layers.core.Activation object at 0x4699b7390>
# <keras.layers.core.Activation object at 0x469c54e48>
# <keras.layers.core.Activation object at 0x469ecd6a0>
# <keras.layers.core.Activation object at 0x46a2a5a20>
# <keras.layers.convolutional.SeparableConv2D object at 0x469825f60>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x4699cfdd8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x469c9a630>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x469f12c18>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46a2a5978>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x46987a518>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469abffd0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469d75f60>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469fcef60>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46a2b61d0>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x469866f28>
# <keras.layers.core.Activation object at 0x469af87b8>
# <keras.layers.core.Activation object at 0x469d92278>
# <keras.layers.core.Activation object at 0x46a007ac8>
# <keras.layers.core.Activation object at 0x46a2b64a8>
# <keras.layers.convolutional.SeparableConv2D object at 0x4698dff98>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x469b3fd30>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x469da6cc0>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46a01feb8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46a2c9ef0>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x469985ba8>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469bfce80>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x469e95eb8>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46a130748>
# (88,)
# (1, 88)
# <keras.layers.pooling.AveragePooling2D object at 0x46a149ef0>
# <keras.layers.pooling.AveragePooling2D object at 0x46a222860>
# <keras.layers.pooling.AveragePooling2D object at 0x46a26eb70>
# <keras.layers.normalization.BatchNormalization object at 0x46a3b9d68>
# (88,)
# (1, 88)
# <keras.layers.merge.Add object at 0x469791400>
# <keras.layers.merge.Add object at 0x469c38be0>
# <keras.layers.merge.Add object at 0x46a177978>
# <keras.layers.merge.Add object at 0x46a2a5358>
# <keras.layers.merge.Add object at 0x46a2a57b8>
# <keras.layers.merge.Concatenate object at 0x469733400>
# <keras.layers.core.Activation object at 0x46a454320>
# <keras.layers.core.Activation object at 0x46a3ef8d0>
# <keras.layers.convolutional.Conv2D object at 0x46a4544a8>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 2.8282
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.7103168105675195 0.09402556742827362 PL
# <keras.layers.convolutional.Conv2D object at 0x46a4a7cf8>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 3.9148
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.018378607513695 0.07692307692307676 PL
# <keras.layers.normalization.BatchNormalization object at 0x46a4f1e80>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46a54b6a0>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x46a714668>
# <keras.layers.core.Activation object at 0x46a8c36d8>
# <keras.layers.core.Activation object at 0x46ab73860>
# <keras.layers.core.Activation object at 0x46add89e8>
# <keras.layers.core.Activation object at 0x46b1aff28>
# <keras.layers.convolutional.SeparableConv2D object at 0x46a7572e8>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46a90cc50>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46ab739b0>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46adf2dd8>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46b1afcc0>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x46a774eb8>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46a9caf98>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46ac9c2e8>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46af02668>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46b1c3518>
# (88,)
# (1, 88)
# <keras.layers.core.Activation object at 0x46a78a2b0>
# <keras.layers.core.Activation object at 0x46aa04b00>
# <keras.layers.core.Activation object at 0x46ac9c5c0>
# <keras.layers.core.Activation object at 0x46af1be10>
# <keras.layers.core.Activation object at 0x46b1c37f0>
# <keras.layers.convolutional.SeparableConv2D object at 0x46a79ecf8>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46aa1eef0>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46acb48d0>
# (5, 5, 88, 1)
# (88, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x46af4d898>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x46b206d68>
# (3, 3, 88, 1)
# (88, 9)
# <keras.layers.normalization.BatchNormalization object at 0x46a88cef0>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46ab2e780>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46ad9ee80>
# (88,)
# (1, 88)
# <keras.layers.normalization.BatchNormalization object at 0x46b03da90>
# (88,)
# (1, 88)
# <keras.layers.pooling.AveragePooling2D object at 0x46b074278>
# <keras.layers.pooling.AveragePooling2D object at 0x46b153f60>
# <keras.layers.pooling.AveragePooling2D object at 0x46b178eb8>
# <keras.layers.normalization.BatchNormalization object at 0x46b2c1eb8>
# (88,)
# (1, 88)
# <keras.layers.merge.Add object at 0x46a6a0748>
# <keras.layers.merge.Add object at 0x46ab44f28>
# <keras.layers.merge.Add object at 0x46b088cc0>
# <keras.layers.merge.Add object at 0x46b1af6a0>
# <keras.layers.merge.Add object at 0x46b1afb00>
# <keras.layers.merge.Concatenate object at 0x46a637748>
# <keras.layers.core.Activation object at 0x46b300c18>
# <keras.layers.core.Activation object at 0x46b3635c0>
# <keras.layers.convolutional.Conv2D object at 0x46b31ae10>
# (1, 1, 528, 176)
# (528, 176)
# % spikes outside bulk 0.00
# % sigma 2.9481
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.172042357316762 0.06162914851628487 PL
# <keras.layers.convolutional.Conv2D object at 0x46b3637f0>
# (1, 1, 528, 176)
# (528, 176)
# % spikes outside bulk 0.00
# % sigma 2.4524
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.0728595849912814 0.08583070460691755 PL
# <keras.layers.normalization.BatchNormalization object at 0x46b45c9e8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x46b425208>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x46b6219b0>
# <keras.layers.core.Activation object at 0x412331978>
# <keras.layers.convolutional.SeparableConv2D object at 0x46b667630>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x4122e09b0>
# (7, 7, 176, 1)
# (176, 49)
# % spikes outside bulk 0.00
# % sigma 0.1945
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 5.328739133190183 0.2497493271416602 PL
# <keras.layers.normalization.BatchNormalization object at 0x46b69f240>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x4098999b0>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x46b69f5f8>
# <keras.layers.core.Activation object at 0x4098ae588>
# <keras.layers.convolutional.SeparableConv2D object at 0x411cd77b8>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x4098b7dd8>
# (7, 7, 176, 1)
# (176, 49)
# % spikes outside bulk 0.00
# % sigma 0.1994
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.535281496834447 0.22425204432381873 EXP
# <keras.layers.normalization.BatchNormalization object at 0x41200bcc0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40991e2e8>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x409999fd0>
# <keras.layers.merge.Add object at 0x46b5ada90>
# <keras.layers.convolutional.SeparableConv2D object at 0x4099a3940>
# (7, 7, 176, 1)
# (176, 49)
# % spikes outside bulk 0.00
# % sigma 0.7973
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 4.138202239977069 0.14165974321343688 PL
# <keras.layers.core.Activation object at 0x409ab8dd8>
# <keras.layers.core.Activation object at 0x409bd94e0>
# <keras.layers.normalization.BatchNormalization object at 0x4099b8cc0>
# (176,)
# (1, 176)
# <keras.layers.convolutional.SeparableConv2D object at 0x409ac3710>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x409bec780>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.core.Activation object at 0x4099c2438>
# <keras.layers.normalization.BatchNormalization object at 0x409ad7fd0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x409becd68>
# (176,)
# (1, 176)
# <keras.layers.convolutional.SeparableConv2D object at 0x4099cda58>
# (7, 7, 176, 1)
# (176, 49)
# % spikes outside bulk 0.00
# % sigma 1.3643
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 2.5527099416100025 0.11757432493740838 PL
# <keras.layers.core.Activation object at 0x409ae2be0>
# <keras.layers.core.Activation object at 0x409bf6b70>
# <keras.layers.pooling.MaxPooling2D object at 0x409932940>
# <keras.layers.normalization.BatchNormalization object at 0x409a34ef0>
# (176,)
# (1, 176)
# <keras.layers.convolutional.SeparableConv2D object at 0x409aec978>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x409c02b00>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.core.Activation object at 0x409cf7780>
# <keras.layers.merge.Add object at 0x40993c048>
# <keras.layers.pooling.AveragePooling2D object at 0x409a462b0>
# <keras.layers.normalization.BatchNormalization object at 0x409b53630>
# (176,)
# (1, 176)
# <keras.layers.pooling.AveragePooling2D object at 0x409b665f8>
# <keras.layers.normalization.BatchNormalization object at 0x409c67518>
# (176,)
# (1, 176)
# <keras.layers.pooling.MaxPooling2D object at 0x409b86e80>
# <keras.layers.convolutional.ZeroPadding2D object at 0x409d0b860>
# <keras.layers.merge.Add object at 0x409a536d8>
# <keras.layers.merge.Add object at 0x409b70e10>
# <keras.layers.merge.Add object at 0x409c20320>
# <keras.layers.convolutional.Cropping2D object at 0x409d0ba58>
# <keras.layers.merge.Concatenate object at 0x46b546a90>
# <keras.layers.pooling.AveragePooling2D object at 0x409c7fef0>
# <keras.layers.pooling.AveragePooling2D object at 0x409d0bfd0>
# <keras.layers.convolutional.Conv2D object at 0x409cec828>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 1.6561
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 9.249796907286335 0.11111111111111094 PL
# <keras.layers.convolutional.Conv2D object at 0x409d15d68>
# (1, 1, 528, 88)
# (528, 88)
# % spikes outside bulk 0.00
# % sigma 1.5715
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 6.457386836016701 0.1362886249994254 PL
# <keras.layers.core.Activation object at 0x46b57de10>
# <keras.layers.merge.Concatenate object at 0x409d21e10>
# <keras.layers.convolutional.Conv2D object at 0x46b57d898>
# (1, 1, 704, 176)
# (704, 176)
# % spikes outside bulk 0.00
# % sigma 2.6266
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.514903783507334 0.04197040167419486 PL
# <keras.layers.normalization.BatchNormalization object at 0x409d21400>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x409d2cf60>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x409dec550>
# <keras.layers.core.Activation object at 0x409ea6940>
# <keras.layers.core.Activation object at 0x409fbbbe0>
# <keras.layers.core.Activation object at 0x40a0c5dd8>
# <keras.layers.core.Activation object at 0x40a2615f8>
# <keras.layers.convolutional.SeparableConv2D object at 0x409e02898>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x409edaeb8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x409fd9cf8>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a0cf9e8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a261748>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x409e22a20>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x409f16860>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a040518>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a136828>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a261da0>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x409e16be0>
# <keras.layers.core.Activation object at 0x409f2a400>
# <keras.layers.core.Activation object at 0x40a036c50>
# <keras.layers.core.Activation object at 0x40a14b5f8>
# <keras.layers.core.Activation object at 0x40a2686a0>
# <keras.layers.convolutional.SeparableConv2D object at 0x409e3fb70>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x409f38a20>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a05eda0>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a155e48>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a2750f0>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x409e884a8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x409f9c940>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a0a7ef0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a1bbe48>
# (176,)
# (1, 176)
# <keras.layers.pooling.AveragePooling2D object at 0x40a1779b0>
# <keras.layers.pooling.AveragePooling2D object at 0x40a22d978>
# <keras.layers.pooling.AveragePooling2D object at 0x40a240f28>
# <keras.layers.normalization.BatchNormalization object at 0x40a2db160>
# (176,)
# (1, 176)
# <keras.layers.merge.Add object at 0x409db0d30>
# <keras.layers.merge.Add object at 0x409fb1860>
# <keras.layers.merge.Add object at 0x40a1d1b70>
# <keras.layers.merge.Add object at 0x40a256e48>
# <keras.layers.merge.Add object at 0x40a261128>
# <keras.layers.merge.Concatenate object at 0x409d925f8>
# <keras.layers.core.Activation object at 0x40a318cc0>
# <keras.layers.core.Activation object at 0x40a2fa128>
# <keras.layers.convolutional.Conv2D object at 0x40a35f780>
# (1, 1, 704, 176)
# (704, 176)
# % spikes outside bulk 0.00
# % sigma 3.7010
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.772605853913733 0.0683555980150723 PL
# <keras.layers.convolutional.Conv2D object at 0x40a34c7b8>
# (1, 1, 1056, 176)
# (1056, 176)
# % spikes outside bulk 0.00
# % sigma 3.5925
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.927652778851406 0.03925663945832003 PL
# <keras.layers.normalization.BatchNormalization object at 0x40a35fdd8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a380fd0>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40a437908>
# <keras.layers.core.Activation object at 0x40a4f1da0>
# <keras.layers.core.Activation object at 0x40a610c88>
# <keras.layers.core.Activation object at 0x40a70f1d0>
# <keras.layers.core.Activation object at 0x40a8b40f0>
# <keras.layers.convolutional.SeparableConv2D object at 0x40a4562e8>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a51b978>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a62f978>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a7377b8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a8b41d0>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40a46bb00>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a556f98>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a68a7f0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a794f60>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a8b4a20>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40a46b588>
# <keras.layers.core.Activation object at 0x40a582940>
# <keras.layers.core.Activation object at 0x40a68aac8>
# <keras.layers.core.Activation object at 0x40a79f278>
# <keras.layers.core.Activation object at 0x40a8b4fd0>
# <keras.layers.convolutional.SeparableConv2D object at 0x40a47fb38>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a58cef0>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a69f9e8>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a7a9390>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40a8df240>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40a4dd7b8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a5f20b8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a6fcef0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a80fc50>
# (176,)
# (1, 176)
# <keras.layers.pooling.AveragePooling2D object at 0x40a825780>
# <keras.layers.pooling.AveragePooling2D object at 0x40a882470>
# <keras.layers.pooling.AveragePooling2D object at 0x40a8aaeb8>
# <keras.layers.normalization.BatchNormalization object at 0x40a9261d0>
# (176,)
# (1, 176)
# <keras.layers.merge.Add object at 0x40a40e780>
# <keras.layers.merge.Add object at 0x40a6065f8>
# <keras.layers.merge.Add object at 0x40a830c18>
# <keras.layers.merge.Add object at 0x40a8a1240>
# <keras.layers.merge.Add object at 0x40a8a1908>
# <keras.layers.merge.Concatenate object at 0x40a3dc128>
# <keras.layers.core.Activation object at 0x40a96e710>
# <keras.layers.core.Activation object at 0x40a3f0908>
# <keras.layers.convolutional.Conv2D object at 0x40a96e940>
# (1, 1, 1056, 176)
# (1056, 176)
# % spikes outside bulk 0.00
# % sigma 3.4878
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.065705069242721 0.06421299667308922 PL
# <keras.layers.convolutional.Conv2D object at 0x40a3e5080>
# (1, 1, 1056, 176)
# (1056, 176)
# % spikes outside bulk 0.00
# % sigma 4.5770
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.586190303980468 0.09511198425614076 PL
# <keras.layers.normalization.BatchNormalization object at 0x40a9b5d30>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40a9caf98>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40aa98d68>
# <keras.layers.core.Activation object at 0x40ab45710>
# <keras.layers.core.Activation object at 0x40ac71c88>
# <keras.layers.core.Activation object at 0x40ad6fa20>
# <keras.layers.core.Activation object at 0x40af09860>
# <keras.layers.convolutional.SeparableConv2D object at 0x40aaa2470>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40ab4e940>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40ac8d668>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40ad835c0>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40af09828>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40aad33c8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40abbf438>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40aceb358>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40addeac8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40af14c18>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40aad38d0>
# <keras.layers.core.Activation object at 0x40abd7da0>
# <keras.layers.core.Activation object at 0x40aceb978>
# <keras.layers.core.Activation object at 0x40adf52b0>
# <keras.layers.core.Activation object at 0x40af14710>
# <keras.layers.convolutional.SeparableConv2D object at 0x40aabfc50>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40abfeac8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40acf5ef0>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40ae13d30>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40af3eb38>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40ab31dd8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40ac46208>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40ad5bbe0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40ae67860>
# (176,)
# (1, 176)
# <keras.layers.pooling.AveragePooling2D object at 0x40ae84cf8>
# <keras.layers.pooling.AveragePooling2D object at 0x40aed6b38>
# <keras.layers.pooling.AveragePooling2D object at 0x40aef5ef0>
# <keras.layers.normalization.BatchNormalization object at 0x40af84710>
# (176,)
# (1, 176)
# <keras.layers.merge.Add object at 0x40aa59dd8>
# <keras.layers.merge.Add object at 0x40ac66048>
# <keras.layers.merge.Add object at 0x40ae90908>
# <keras.layers.merge.Add object at 0x40af09208>
# <keras.layers.merge.Add object at 0x40af09668>
# <keras.layers.merge.Concatenate object at 0x40aa2f860>
# <keras.layers.core.Activation object at 0x40afcda58>
# <keras.layers.core.Activation object at 0x40af9afd0>
# <keras.layers.convolutional.Conv2D object at 0x40afcdbe0>
# (1, 1, 1056, 176)
# (1056, 176)
# % spikes outside bulk 0.00
# % sigma 3.0712
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 5.916139305733337 0.10193107378939559 PL
# <keras.layers.convolutional.Conv2D object at 0x40b000390>
# (1, 1, 1056, 176)
# (1056, 176)
# % spikes outside bulk 0.00
# % sigma 2.9626
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# 4.906119693096668 0.09521359236089288 PL
# <keras.layers.normalization.BatchNormalization object at 0x40b00af60>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b029e10>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40b0eba90>
# <keras.layers.core.Activation object at 0x40b1a2320>
# <keras.layers.core.Activation object at 0x40b2c4e48>
# <keras.layers.core.Activation object at 0x40b3c74a8>
# <keras.layers.core.Activation object at 0x40b5608d0>
# <keras.layers.convolutional.SeparableConv2D object at 0x40b101c18>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b1adc18>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b2c40f0>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b3ceeb8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b5609b0>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40b114898>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b2162e8>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b334b00>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b435fd0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b5692b0>
# (176,)
# (1, 176)
# <keras.layers.core.Activation object at 0x40b11e128>
# <keras.layers.core.Activation object at 0x40b228be0>
# <keras.layers.core.Activation object at 0x40b33c2e8>
# <keras.layers.core.Activation object at 0x40b449a90>
# <keras.layers.core.Activation object at 0x40b569630>
# <keras.layers.convolutional.SeparableConv2D object at 0x40b1277f0>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b23f4a8>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b349c88>
# (5, 5, 176, 1)
# (176, 25)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b45e198>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.convolutional.SeparableConv2D object at 0x40b575d68>
# (3, 3, 176, 1)
# (176, 9)
# <keras.layers.normalization.BatchNormalization object at 0x40b18f940>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b29b780>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b3ad5c0>
# (176,)
# (1, 176)
# <keras.layers.normalization.BatchNormalization object at 0x40b4b9f60>
# (176,)
# (1, 176)
# <keras.layers.pooling.AveragePooling2D object at 0x40b4cef98>
# <keras.layers.pooling.AveragePooling2D object at 0x40b50d5c0>
# <keras.layers.pooling.AveragePooling2D object at 0x40b540240>
# <keras.layers.normalization.BatchNormalization object at 0x40b5e55f8>
# (176,)
# (1, 176)
# <keras.layers.merge.Add object at 0x40b0b8a90>
# <keras.layers.merge.Add object at 0x40b2adb70>
# <keras.layers.merge.Add object at 0x40b501390>
# <keras.layers.merge.Add object at 0x40b560278>
# <keras.layers.merge.Add object at 0x40b5606d8>
# <keras.layers.merge.Concatenate object at 0x40b091eb8>
# <keras.layers.core.Activation object at 0x45f98ccf8>
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x40a2f0668>
# <keras.layers.core.Dense object at 0x45f9c4c18>
# (1056, 1000)
# (1056, 1000)
# % spikes outside bulk 0.00
# % sigma 3.1412
# Calculating best minimal value for power law fit
# Assuming nested distributions
# 3.173347833647033 0.041704154647751346 PL

# %%
print(len(alphas))
plt.hist(alphas,bins=30);
plt.title("power law fits, NasNetMobile")
